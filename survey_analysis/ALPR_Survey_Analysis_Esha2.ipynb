# %%
# Imports + settings

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import spearmanr

pd.set_option('display.max_columns', None)

# %%
df_survey = pd.read_csv('/content/ALPR General Survey Results v2.csv')

# %%
df_survey
# Out:
#           Run  Program Version  User   Time Started (UTC)  \
# 0    16180288               34   NaN  2025-07-31 09:21:14
# 1    16180291               34   NaN  2025-07-31 09:22:13
# 2    16180292               34   NaN  2025-07-31 09:22:31
# 3    16180296               34   NaN  2025-07-31 09:22:46
# 4    16180297               34   NaN  2025-07-31 09:22:48
# ..        ...              ...   ...                  ...
# 474  16646718               38   NaN  2025-09-25 15:49:19
# 475  16648785               38   NaN  2025-09-25 19:08:04
# 476  16649867               38   NaN  2025-09-25 21:09:28
# 477  16658812               38   NaN  2025-09-26 15:39:27
# 478  16658980               38   NaN  2025-09-26 15:53:27
#
#      Time Finished (UTC)  Minutes Spent Position  Points  \
# 0                    NaN           5.62  7h99xur       0
# 1                    NaN           3.93  7h99xur       0
# 2                    NaN           3.43  7h99xur       0
# 3                    NaN           3.77  7h99xur       0
# 4                    NaN           3.85  7h99xur       0
# ..                   ...            ...      ...     ...
# 474                  NaN           8.63  7h99xur       0
# 475                  NaN           5.15  7h99xur       0
# 476                  NaN           5.55  7h99xur       0
# 477                  NaN           3.62  7h99xur       0
# 478                  NaN           1.35  7h99xur       0
#
#      testing question? (8vufenf)  \
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# ..                           ...
# 474                          NaN
# 475                          NaN
# 476                          NaN
# 477                          NaN
# 478                          NaN
#
#     Have you noticed surveillance technologies in your neighborhood that were installed by the government, police, or private businesses (not personal home cameras like Ring or Nest)? (lw3083d)  \
# 0                                                  Yes
# 1                                                   No
# 2                                                   No
# 3                                                  Yes
# 4                                                   No
# ..                                                 ...
# 474                                                Yes
# 475                                                Yes
# 476                                           Not sure
# 477                                                 No
# 478                                                Yes
#
#     What is your ZIP code? (7bepp7b) participantID assignmentID  projectID  \
# 0                              59901     pc08b1cf8    pb0567325  pffe2652f
# 1                              91803     pa376c666    pc0ee7509  pffe2652f
# 2                              30180     pcf714afc    pf0e97ff0  pffe2652f
# 3                              68147     pcefc07bd    pb306b2e0  pffe2652f
# 4                              77506     pf9178409    pfbf53752  pffe2652f
# ..                               ...           ...          ...        ...
# 474                            94102     pf59512b9    pdd5471fa  pffe2652f
# 475                            94605     pcbfa4b18    pbed380dd  pffe2652f
# 476                            94611     pd4a54585    pabced9de  pffe2652f
# 477                            94110     pfa932d74    pd383af85  pffe2652f
# 478                            94109     pfb1ff4c5    pf0c4fd65  pffe2652f
#
#                startedAt computerCountry  \
# 0    2025/07/31 02:20 AM   United States
# 1    2025/07/31 02:20 AM   United States
# 2    2025/07/31 02:20 AM   United States
# 3    2025/07/31 02:21 AM   United States
# 4    2025/07/31 02:20 AM   United States
# ..                   ...             ...
# 474  2025/09/25 08:45 AM   United States
# 475  2025/09/25 12:04 PM   United States
# 476  2025/09/25 02:08 PM   United States
# 477  2025/09/26 08:37 AM   United States
# 478  2025/09/26 08:52 AM   United States
#
#                                    computerID      device  \
# 0    ba3bd667909e79c1be729c53c9642ac6098082f9  smartphone
# 1    e1aa0e8ed7491fba136b8aa20ea790746bf006dc     desktop
# 2    88ad1a3dc55fad51c7ec04e75810f654980cc700  smartphone
# 3    bf0acb9ece93e2dadeae3371b38deca1b5ae540f  smartphone
# 4    a4ff75334e7171bcf8650cadefe2c86a7b9298d3  smartphone
# ..                                        ...         ...
# 474  459187c95ac0b8d58cc128809f199ec576baf980  smartphone
# 475  0f358509ddf66d953fc79fea6ed1c422654ed76f  smartphone
# 476  bbba5821dea8d68471e1f36b535706ef2dc9f94c     desktop
# 477  c9ec7009d852cf69727aac31a1d7faa4b41f0003  smartphone
# 478  b6a27eefd7e820be0b2b2bdb37db27058021f364     desktop
#
#     Which of the following surveillance tools have you heard of or seen in your city? (Select all that apply) (8dl9hmt)  \
# 0    Surveillance/security cameras,Automatic Licens...
# 1    Automatic License Plate Readers (ALPRs),Speed ...
# 2    Surveillance/security cameras,Automatic Licens...
# 3    Surveillance/security cameras,Automatic Licens...
# 4    Surveillance/security cameras,Drones,Facial re...
# ..                                                 ...
# 474        Surveillance/security cameras,Speed Cameras
# 475  Surveillance/security cameras,Drones,Facial re...
# 476  Surveillance/security cameras,Automatic Licens...
# 477  Automatic License Plate Readers (ALPRs),Speed ...
# 478  Surveillance/security cameras,Automatic Licens...
#
#     How concerned are you about surveillance technology in public spaces like streets, sidewalks, or public transit? (n15scu9)  \
# 0                             3 = Moderately concerned
# 1                             3 = Moderately concerned
# 2                             3 = Moderately concerned
# 3                             3 = Moderately concerned
# 4                             1 = Not at all concerned
# ..                                                 ...
# 474                           3 = Moderately concerned
# 475                           3 = Moderately concerned
# 476                           1 = Not at all concerned
# 477                             2 = Slightly concerned
# 478                           3 = Moderately concerned
#
#     How often do you notice surveillance cameras or sensors in your neighborhood or daily routine? (6itkmu)  \
# 0                                        3 = Sometimes
# 1                                            1 = Never
# 2                                            1 = Never
# 3                                        3 = Sometimes
# 4                                           2 = Rarely
# ..                                                 ...
# 474                                      3 = Sometimes
# 475                                      3 = Sometimes
# 476                                          1 = Never
# 477                                      3 = Sometimes
# 478                                      3 = Sometimes
#
#     How familiar are you with how automatic license plate reader (ALPR) cameras work? (724al0n)  \
# 0                                2 = Slightly familiar
# 1                                2 = Slightly familiar
# 2                              1 = Not at all familiar
# 3                                3 = Somewhat familiar
# 4                              1 = Not at all familiar
# ..                                                 ...
# 474                                  4 = Very familiar
# 475                              2 = Slightly familiar
# 476                              3 = Somewhat familiar
# 477                            1 = Not at all familiar
# 478                              3 = Somewhat familiar
#
#     After being approved by local governments, private companies like Flock Safety install Automatic License Plate Reader (ALPR) cameras in neighborhoods and share data with police. Before today, how aware were you of that fact? (50mnfkf)  \
# 0                                 1 = Not at all aware
# 1                                 1 = Not at all aware
# 2                                 1 = Not at all aware
# 3                                 1 = Not at all aware
# 4                                 1 = Not at all aware
# ..                                                 ...
# 474                                 3 = Somewhat aware
# 475                                 2 = Slightly aware
# 476                               1 = Not at all aware
# 477                               1 = Not at all aware
# 478                                 3 = Somewhat aware
#
#     In some Bay Area cities, Automatic License Plate Reader (ALPR) cameras store an image of your license plate, vehicle make and model, and location in a searchable database for up to 12 months every time you drive past one. Before today, how aware were you of that fact? (6s6r3ex)  \
# 0                                 1 = Not at all aware
# 1                                   3 = Somewhat aware
# 2                                 1 = Not at all aware
# 3                                 1 = Not at all aware
# 4                                 1 = Not at all aware
# ..                                                 ...
# 474                               1 = Not at all aware
# 475                                 2 = Slightly aware
# 476                                     4 = Very aware
# 477                               1 = Not at all aware
# 478                                 3 = Somewhat aware
#
#     Police can search the Automatic License Plate Reader (ALPR) database for your data without a warrant or approval from any other organization. Before today, how aware were you of that fact? (zke2ete)  \
# 0                                      5 = Fully aware
# 1                                   2 = Slightly aware
# 2                                 1 = Not at all aware
# 3                                 1 = Not at all aware
# 4                                 1 = Not at all aware
# ..                                                 ...
# 474                               1 = Not at all aware
# 475                                 2 = Slightly aware
# 476                                 2 = Slightly aware
# 477                               1 = Not at all aware
# 478                                 3 = Somewhat aware
#
#     Police can legally share your license plate Automatic License Plate Reader (ALPR) data with other local governments/police departments within California at any time without a warrant. Before today, how aware were you of that fact? (skzr4a8)  \
# 0                                   2 = Slightly aware
# 1                                   3 = Somewhat aware
# 2                                 1 = Not at all aware
# 3                                 1 = Not at all aware
# 4                                 1 = Not at all aware
# ..                                                 ...
# 474                                 2 = Slightly aware
# 475                                 2 = Slightly aware
# 476                                 3 = Somewhat aware
# 477                                 2 = Slightly aware
# 478                                 3 = Somewhat aware
#
#     The image above shows locations and number of Automatic License Plate Reader (ALPR) cameras in the Bay Area reported by residents. Actual locations and counts may vary, but there is likely to be more installed than shown in the image. Before today, how aware were you of the number of ALPR cameras in the Bay Area? (3eg0nl6)  \
# 0                                 1 = Not at all aware
# 1                                 1 = Not at all aware
# 2                                 1 = Not at all aware
# 3                                 1 = Not at all aware
# 4                                 1 = Not at all aware
# ..                                                 ...
# 474                               1 = Not at all aware
# 475                               1 = Not at all aware
# 476                                 2 = Slightly aware
# 477                               1 = Not at all aware
# 478                                 3 = Somewhat aware
#
#     How supportive are you of Automatic License Plate Reader (ALPR) cameras installed by local governments and used by law enforcement? (y7ka0mc)  \
# 0                               3 = Neutral / Not sure
# 1                                  2 = Somewhat oppose
# 2                                  1 = Strongly oppose
# 3                                  1 = Strongly oppose
# 4                               3 = Neutral / Not sure
# ..                                                 ...
# 474                             3 = Neutral / Not sure
# 475                             3 = Neutral / Not sure
# 476                               5 = Strongly support
# 477                                1 = Strongly oppose
# 478                               4 = Somewhat support
#
#     How supportive are you of private individuals or businesses installing Automatic License Plate Reader (ALPR) cameras and sharing the data voluntarily with police? (uktyzgu)  \
# 0                                  2 = Somewhat oppose
# 1                               3 = Neutral / Not sure
# 2                               3 = Neutral / Not sure
# 3                                  1 = Strongly oppose
# 4                               3 = Neutral / Not sure
# ..                                                 ...
# 474                               4 = Somewhat support
# 475                                2 = Somewhat oppose
# 476                               4 = Somewhat support
# 477                                1 = Strongly oppose
# 478                               4 = Somewhat support
#
#     Have you ever felt uncomfortable or treated unfairly due to surveillance technology? (5bdjc2c)  \
# 0                                                   No
# 1                                                  Yes
# 2                                                   No
# 3                                                  Yes
# 4                                                   No
# ..                                                 ...
# 474                                                 No
# 475                                                 No
# 476                                                 No
# 477                                                 No
# 478                                           Not sure
#
#     How concerned are you that surveillance technologies may harm others (e.g., unhoused people, immigrants, protesters), even if they don’t affect you personally? (gvrrsub)  \
# 0                             3 = Moderately concerned
# 1                             3 = Moderately concerned
# 2                             3 = Moderately concerned
# 3                                   4 = Very concerned
# 4                             3 = Moderately concerned
# ..                                                 ...
# 474                                 4 = Very concerned
# 475                                 4 = Very concerned
# 476                             2 = Slightly concerned
# 477                             2 = Slightly concerned
# 478                           3 = Moderately concerned
#
#     Do you believe surveillance is being used more for public safety or social control? (cfu4j56)  \
# 0                                     3 = Equally both
# 1                        4 = Mostly for social control
# 2                      5 = Entirely for social control
# 3                      5 = Entirely for social control
# 4                                     3 = Equally both
# ..                                                 ...
# 474                                   3 = Equally both
# 475                                   3 = Equally both
# 476                       2 = Mostly for public safety
# 477                      4 = Mostly for social control
# 478                                   3 = Equally both
#
#     Which of the following groups should have access to surveillance data? (Select all that apply) (bgnrn84)  \
# 0                            Police,Federal Government
# 1           Police,Local government,Federal Government
# 2                   No one — it shouldn’t be collected
# 3                   No one — it shouldn’t be collected
# 4                                               Police
# ..                                                 ...
# 474                                             Police
# 475                                             Police
# 476         Police,Local government,Federal Government
# 477                 No one — it shouldn’t be collected
# 478               Private companies,Federal Government
#
#     Who do you trust to make decisions about how surveillance is used in your city? (Select all that apply) (w02ux9i)  \
# 0            Community organizations,Community members
# 1                                    Police department
# 2    Local elected officials,Police department,Comm...
# 3            Community organizations,Community members
# 4                                    Police department
# ..                                                 ...
# 474  Local elected officials,Community organization...
# 475          Community organizations,Community members
# 476          Local elected officials,Police department
# 477                                  Police department
# 478          Police department,Community organizations
#
#     How important is it to you that the public has input or oversight before new surveillance technologies are adopted? (ttzmqna)  \
# 0                             3 = Moderately important
# 1                             3 = Moderately important
# 2                             3 = Moderately important
# 3                                   4 = Very important
# 4                             5 = Absolutely essential
# ..                                                 ...
# 474                                 4 = Very important
# 475                           3 = Moderately important
# 476                                 4 = Very important
# 477                             2 = Slightly important
# 478                           3 = Moderately important
#
#     How likely do you think it is that police would share Automatic License Plate Reader (ALPR) data with federal agencies, even if not legally allowed? (gnnu4ft)  \
# 0                                           4 = Likely
# 1                                         2 = Unlikely
# 2                                           4 = Likely
# 3                                    1 = Very unlikely
# 4                                      5 = Very likely
# ..                                                 ...
# 474                                    5 = Very likely
# 475                                    5 = Very likely
# 476                                         3 = Unsure
# 477                                       2 = Unlikely
# 478                                         4 = Likely
#
#     It’s okay for police to track and store the location data of people who haven’t done anything wrong. (nd9oynf)  \
# 0                                2 = Somewhat disagree
# 1                                          3 = Neutral
# 2                                2 = Somewhat disagree
# 3                                1 = Strongly disagree
# 4                                1 = Strongly disagree
# ..                                                 ...
# 474                                 5 = Strongly agree
# 475                              1 = Strongly disagree
# 476                                 4 = Somewhat agree
# 477                              1 = Strongly disagree
# 478                                 4 = Somewhat agree
#
#     Surveillance technologies such as ALPRs disproportionately impact marginalized communities (e.g., by race, income, housing status, or immigration status)? (f1j1olu)  \
# 0                                   4 = Somewhat agree
# 1                                2 = Somewhat disagree
# 2                                          3 = Neutral
# 3                                1 = Strongly disagree
# 4                                          3 = Neutral
# ..                                                 ...
# 474                                 5 = Strongly agree
# 475                              2 = Somewhat disagree
# 476                              2 = Somewhat disagree
# 477                              2 = Somewhat disagree
# 478                                 4 = Somewhat agree
#
#     Surveillance technologies such as ALPRs increase public safety. (u84m4pd)  \
# 0                                   4 = Somewhat agree
# 1                                          3 = Neutral
# 2                                2 = Somewhat disagree
# 3                                          3 = Neutral
# 4                                          3 = Neutral
# ..                                                 ...
# 474                                 4 = Somewhat agree
# 475                                        3 = Neutral
# 476                                 5 = Strongly agree
# 477                                        3 = Neutral
# 478                                 4 = Somewhat agree
#
#     What should be done about ALPRs in your city? Select all that apply (vwzlz5r)  \
# 0    Require more safeguards (e.g., limits on use, ...
# 1    Require more safeguards (e.g., limits on use, ...
# 2    Reduce use,Require more safeguards (e.g., limi...
# 3          Ban them,Reduce use,Require public approval
# 4    Require more transparency,Require public appro...
# ..                                                 ...
# 474  Require more safeguards (e.g., limits on use, ...
# 475  Require more safeguards (e.g., limits on use, ...
# 476                            Keep things as they are
# 477  Reduce use,Require more safeguards (e.g., limi...
# 478  Reduce use,Require more safeguards (e.g., limi...
#
#     What is your race or ethnicity? (Select all that apply) (d8morv7)  \
# 0                                                White
# 1                            Asian or Pacific Islander
# 2                                                White
# 3                                                White
# 4                                                White
# ..                                                 ...
# 474                                 Hispanic or Latino
# 475                                 Hispanic or Latino
# 476                          Asian or Pacific Islander
# 477                                 Hispanic or Latino
# 478                          Asian or Pacific Islander
#
#     How did you find this survey? (yyxwhnl)  age  gender  \
# 0                                   Episode   22  female
# 1                              quickrewards   35  female
# 2                                    klover   23  female
# 3                                      Imvu   22  female
# 4                                      Pogo   43  female
# ..                                      ...  ...     ...
# 474  Design Home mobile game ➡️ Tap Surveys   27    male
# 475                                Attapoll   25    male
# 476                                   Email   78    male
# 477                                  Survey   45  female
# 478                                  google   37    male
#
#                                   education  yearOfBirth  educationScore  \
# 0    completedOnlyHighSchoolOrTheEquivalent         2003               2
# 1                  completedBachelorsDegree         1990               5
# 2                  completedBachelorsDegree         2002               5
# 3    completedOnlyHighSchoolOrTheEquivalent         2003               2
# 4    completedTradeTechicalVocationalTraing         1982               3
# ..                                      ...          ...             ...
# 474                completedBachelorsDegree         1998               5
# 475                completedBachelorsDegree         2000               5
# 476                completedBachelorsDegree         1947               5
# 477            completedAssociateDegreeOnly         1980               4
# 478                  completedMastersDegree         1988               6
#
#     politicalViews       householdIncome  femaleAs1MaleAs0  \
# 0         Moderate   $85,000 to $114,999               1.0
# 1         Moderate    $40,000 to $59,999               1.0
# 2     Conservative   $85,000 to $114,999               1.0
# 3         Moderate    $25,000 to $39,999               1.0
# 4     Conservative    $25,000 to $39,999               1.0
# ..             ...                   ...               ...
# 474            NaN      $200,000 or more               0.0
# 475            NaN      Less than $9,999               0.0
# 476            NaN    $40,000 to $59,999               0.0
# 477            NaN    $40,000 to $59,999               1.0
# 478            NaN  $150,000 to $199,999               0.0
#
#      politicalLiberalness  householdIncomeScore  householdIncomeEstimate  \
# 0                     0.0                     5                   100000
# 1                     0.0                     3                    50000
# 2                    -1.0                     5                   100000
# 3                     0.0                     2                    32500
# 4                    -1.0                     2                    32500
# ..                    ...                   ...                      ...
# 474                   NaN                     8                   225000
# 475                   NaN                     0                     4500
# 476                   NaN                     3                    50000
# 477                   NaN                     3                    50000
# 478                   NaN                     7                   175000
#
#     How did surveillance make you feel or impact you? (urjiu1g)  \
# 0                                                  NaN
# 1                                           no privacy
# 2                                                  NaN
# 3       It just makes me feel like they don't trust us
# 4                                                  NaN
# ..                                                 ...
# 474                                                NaN
# 475                                                NaN
# 476                                                NaN
# 477                                                NaN
# 478                                                NaN
#
#     How concerned are you about local Automatic License Plate Reader (ALPR) data being shared with federal agencies like ICE or the FBI? (izclv6s)  \
# 0                               2 = Slightly concerned
# 1                             3 = Moderately concerned
# 2                             3 = Moderately concerned
# 3                             3 = Moderately concerned
# 4                             1 = Not at all concerned
# ..                                                 ...
# 474                            5 = Extremely concerned
# 475                            5 = Extremely concerned
# 476                             2 = Slightly concerned
# 477                           1 = Not at all concerned
# 478                           3 = Moderately concerned
#
#     The San Francisco Standard recently reported that the San Francisco and Oakland Police Departments shared Automatic License Plate Reader (ALPR) data with federal agencies like ICE — in violation of state law. How concerned does this make you feel? (dgwct6r)
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 474                            5 = Extremely concerned
# 475                            5 = Extremely concerned
# 476                             2 = Slightly concerned
# 477                             2 = Slightly concerned
# 478                                 4 = Very concerned
#
# [479 rows x 56 columns]

# %%
df_survey['What is your ZIP code? (7bepp7b)'].unique()
# Out:
# array(['59901', '91803', '30180', '68147', '77506', '15226', '77502', nan,
#        '43612', '40186', '17406', '73013', '93308', '38108', '77089',
#        '87106', '55118', '67210', '95815', '86440', '94561', '94578',
#        '94611', '94122', '90001', '94026', '95688', '94061', '94103',
#        '94608', '94505', '95120', '94403', '97415', '94080', '95403',
#        '95123', '94579', '94547', '94536', '94928', '95035', '95112',
#        '94404', '94102', '95125', '95014', '94025', '94115', '94587',
#        '94063', '95076', '94544', '94109', '94070', '95618', '95616',
#        '94590', '94596', '94805', '95116', '94564', '95148', '45044',
#        '94708', '95242', '94565', '95219', '94521', '95304', '94542',
#        '94533', '93635', '94606', '94577', '94954', '94523', '95020',
#        '95448', '95687', '94086', '95121', '94105', '95008', '94801',
#        '95360', '94591', '04-43', '94089', '95129', '94551', '97214',
#        '94118', '94134', '94040', '94066', '94124', '94541', '95050',
#        '94582', '94552', '94560', '94306', '95023', '94515', '94303',
#        '94114', '11218', '94509', '95132', '94132', '95122', '94607',
#        '94621', '94121', '94518', '94301', '94585', '94030', '95037',
#        '94087', '94583', '95377', '94010', '94806', '94110', '94603',
#        '94545', '94108', '94619', '95670', 'You 94521', '94531', '94107',
#        '94502', '95407', '95127', '94501', '94952', '95472', '92782',
#        '94044', '94131', '94803', '94973', '95446', '94598', '95131',
#        '94133', '94513', '95111', '94566', '95492', '94618', '94539',
#        '95054', '94015', '94568', '94804', '95006', '94945', '94085',
#        '94520', '94014', '94601', '94128', '95206', '95070', '94130',
#        '95128', '94580', '91384', '95457', '94703', '95452', '94401',
#        '94065', '95134', '94589', '94548', '94571', '94610', '95401',
#        '95124', '94144', '94558', '94567', '95436', '95405', '94609',
#        '95135', '95620', '94704', '95060', '94602', '94605', '94546',
#        '94588', '95823', '94710', '94158', '90006', '94112', '94116',
#        '90067', '94123', '96816', '90302', ',94102'], dtype=object)

# %%
df_zipmap = pd.read_csv('/content/zip_code_database.csv')

# %%
df_survey["zip_clean"] = (
    df_survey["What is your ZIP code? (7bepp7b)"]
    .astype(str)
    .str.extract(r"(\d{5})")[0]   # keep only 5-digit numbers
)

# %%
df_survey["zip_clean"] = df_survey["zip_clean"].str.zfill(5)
df_zipmap["zip"] = df_zipmap["zip"].astype(str).str.zfill(5)

# %%
df_survey = df_survey.merge(
    df_zipmap[["zip", "primary_city"]],
    left_on="zip_clean",
    right_on="zip",
    how="left"
)

# %%
unmapped = df_survey[df_survey["primary_city"].isna()]["zip_clean"].unique()
print("Unmapped ZIP codes:", unmapped)
# Out:
# Unmapped ZIP codes: [nan '40186']

# %%
df_survey
# Out:
#           Run  Program Version  User   Time Started (UTC)  \
# 0    16180288               34   NaN  2025-07-31 09:21:14
# 1    16180291               34   NaN  2025-07-31 09:22:13
# 2    16180292               34   NaN  2025-07-31 09:22:31
# 3    16180296               34   NaN  2025-07-31 09:22:46
# 4    16180297               34   NaN  2025-07-31 09:22:48
# ..        ...              ...   ...                  ...
# 474  16646718               38   NaN  2025-09-25 15:49:19
# 475  16648785               38   NaN  2025-09-25 19:08:04
# 476  16649867               38   NaN  2025-09-25 21:09:28
# 477  16658812               38   NaN  2025-09-26 15:39:27
# 478  16658980               38   NaN  2025-09-26 15:53:27
#
#      Time Finished (UTC)  Minutes Spent Position  Points  \
# 0                    NaN           5.62  7h99xur       0
# 1                    NaN           3.93  7h99xur       0
# 2                    NaN           3.43  7h99xur       0
# 3                    NaN           3.77  7h99xur       0
# 4                    NaN           3.85  7h99xur       0
# ..                   ...            ...      ...     ...
# 474                  NaN           8.63  7h99xur       0
# 475                  NaN           5.15  7h99xur       0
# 476                  NaN           5.55  7h99xur       0
# 477                  NaN           3.62  7h99xur       0
# 478                  NaN           1.35  7h99xur       0
#
#      testing question? (8vufenf)  \
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# ..                           ...
# 474                          NaN
# 475                          NaN
# 476                          NaN
# 477                          NaN
# 478                          NaN
#
#     Have you noticed surveillance technologies in your neighborhood that were installed by the government, police, or private businesses (not personal home cameras like Ring or Nest)? (lw3083d)  \
# 0                                                  Yes
# 1                                                   No
# 2                                                   No
# 3                                                  Yes
# 4                                                   No
# ..                                                 ...
# 474                                                Yes
# 475                                                Yes
# 476                                           Not sure
# 477                                                 No
# 478                                                Yes
#
#     What is your ZIP code? (7bepp7b) participantID assignmentID  projectID  \
# 0                              59901     pc08b1cf8    pb0567325  pffe2652f
# 1                              91803     pa376c666    pc0ee7509  pffe2652f
# 2                              30180     pcf714afc    pf0e97ff0  pffe2652f
# 3                              68147     pcefc07bd    pb306b2e0  pffe2652f
# 4                              77506     pf9178409    pfbf53752  pffe2652f
# ..                               ...           ...          ...        ...
# 474                            94102     pf59512b9    pdd5471fa  pffe2652f
# 475                            94605     pcbfa4b18    pbed380dd  pffe2652f
# 476                            94611     pd4a54585    pabced9de  pffe2652f
# 477                            94110     pfa932d74    pd383af85  pffe2652f
# 478                            94109     pfb1ff4c5    pf0c4fd65  pffe2652f
#
#                startedAt computerCountry  \
# 0    2025/07/31 02:20 AM   United States
# 1    2025/07/31 02:20 AM   United States
# 2    2025/07/31 02:20 AM   United States
# 3    2025/07/31 02:21 AM   United States
# 4    2025/07/31 02:20 AM   United States
# ..                   ...             ...
# 474  2025/09/25 08:45 AM   United States
# 475  2025/09/25 12:04 PM   United States
# 476  2025/09/25 02:08 PM   United States
# 477  2025/09/26 08:37 AM   United States
# 478  2025/09/26 08:52 AM   United States
#
#                                    computerID      device  \
# 0    ba3bd667909e79c1be729c53c9642ac6098082f9  smartphone
# 1    e1aa0e8ed7491fba136b8aa20ea790746bf006dc     desktop
# 2    88ad1a3dc55fad51c7ec04e75810f654980cc700  smartphone
# 3    bf0acb9ece93e2dadeae3371b38deca1b5ae540f  smartphone
# 4    a4ff75334e7171bcf8650cadefe2c86a7b9298d3  smartphone
# ..                                        ...         ...
# 474  459187c95ac0b8d58cc128809f199ec576baf980  smartphone
# 475  0f358509ddf66d953fc79fea6ed1c422654ed76f  smartphone
# 476  bbba5821dea8d68471e1f36b535706ef2dc9f94c     desktop
# 477  c9ec7009d852cf69727aac31a1d7faa4b41f0003  smartphone
# 478  b6a27eefd7e820be0b2b2bdb37db27058021f364     desktop
#
#     Which of the following surveillance tools have you heard of or seen in your city? (Select all that apply) (8dl9hmt)  \
# 0    Surveillance/security cameras,Automatic Licens...
# 1    Automatic License Plate Readers (ALPRs),Speed ...
# 2    Surveillance/security cameras,Automatic Licens...
# 3    Surveillance/security cameras,Automatic Licens...
# 4    Surveillance/security cameras,Drones,Facial re...
# ..                                                 ...
# 474        Surveillance/security cameras,Speed Cameras
# 475  Surveillance/security cameras,Drones,Facial re...
# 476  Surveillance/security cameras,Automatic Licens...
# 477  Automatic License Plate Readers (ALPRs),Speed ...
# 478  Surveillance/security cameras,Automatic Licens...
#
#     How concerned are you about surveillance technology in public spaces like streets, sidewalks, or public transit? (n15scu9)  \
# 0                             3 = Moderately concerned
# 1                             3 = Moderately concerned
# 2                             3 = Moderately concerned
# 3                             3 = Moderately concerned
# 4                             1 = Not at all concerned
# ..                                                 ...
# 474                           3 = Moderately concerned
# 475                           3 = Moderately concerned
# 476                           1 = Not at all concerned
# 477                             2 = Slightly concerned
# 478                           3 = Moderately concerned
#
#     How often do you notice surveillance cameras or sensors in your neighborhood or daily routine? (6itkmu)  \
# 0                                        3 = Sometimes
# 1                                            1 = Never
# 2                                            1 = Never
# 3                                        3 = Sometimes
# 4                                           2 = Rarely
# ..                                                 ...
# 474                                      3 = Sometimes
# 475                                      3 = Sometimes
# 476                                          1 = Never
# 477                                      3 = Sometimes
# 478                                      3 = Sometimes
#
#     How familiar are you with how automatic license plate reader (ALPR) cameras work? (724al0n)  \
# 0                                2 = Slightly familiar
# 1                                2 = Slightly familiar
# 2                              1 = Not at all familiar
# 3                                3 = Somewhat familiar
# 4                              1 = Not at all familiar
# ..                                                 ...
# 474                                  4 = Very familiar
# 475                              2 = Slightly familiar
# 476                              3 = Somewhat familiar
# 477                            1 = Not at all familiar
# 478                              3 = Somewhat familiar
#
#     After being approved by local governments, private companies like Flock Safety install Automatic License Plate Reader (ALPR) cameras in neighborhoods and share data with police. Before today, how aware were you of that fact? (50mnfkf)  \
# 0                                 1 = Not at all aware
# 1                                 1 = Not at all aware
# 2                                 1 = Not at all aware
# 3                                 1 = Not at all aware
# 4                                 1 = Not at all aware
# ..                                                 ...
# 474                                 3 = Somewhat aware
# 475                                 2 = Slightly aware
# 476                               1 = Not at all aware
# 477                               1 = Not at all aware
# 478                                 3 = Somewhat aware
#
#     In some Bay Area cities, Automatic License Plate Reader (ALPR) cameras store an image of your license plate, vehicle make and model, and location in a searchable database for up to 12 months every time you drive past one. Before today, how aware were you of that fact? (6s6r3ex)  \
# 0                                 1 = Not at all aware
# 1                                   3 = Somewhat aware
# 2                                 1 = Not at all aware
# 3                                 1 = Not at all aware
# 4                                 1 = Not at all aware
# ..                                                 ...
# 474                               1 = Not at all aware
# 475                                 2 = Slightly aware
# 476                                     4 = Very aware
# 477                               1 = Not at all aware
# 478                                 3 = Somewhat aware
#
#     Police can search the Automatic License Plate Reader (ALPR) database for your data without a warrant or approval from any other organization. Before today, how aware were you of that fact? (zke2ete)  \
# 0                                      5 = Fully aware
# 1                                   2 = Slightly aware
# 2                                 1 = Not at all aware
# 3                                 1 = Not at all aware
# 4                                 1 = Not at all aware
# ..                                                 ...
# 474                               1 = Not at all aware
# 475                                 2 = Slightly aware
# 476                                 2 = Slightly aware
# 477                               1 = Not at all aware
# 478                                 3 = Somewhat aware
#
#     Police can legally share your license plate Automatic License Plate Reader (ALPR) data with other local governments/police departments within California at any time without a warrant. Before today, how aware were you of that fact? (skzr4a8)  \
# 0                                   2 = Slightly aware
# 1                                   3 = Somewhat aware
# 2                                 1 = Not at all aware
# 3                                 1 = Not at all aware
# 4                                 1 = Not at all aware
# ..                                                 ...
# 474                                 2 = Slightly aware
# 475                                 2 = Slightly aware
# 476                                 3 = Somewhat aware
# 477                                 2 = Slightly aware
# 478                                 3 = Somewhat aware
#
#     The image above shows locations and number of Automatic License Plate Reader (ALPR) cameras in the Bay Area reported by residents. Actual locations and counts may vary, but there is likely to be more installed than shown in the image. Before today, how aware were you of the number of ALPR cameras in the Bay Area? (3eg0nl6)  \
# 0                                 1 = Not at all aware
# 1                                 1 = Not at all aware
# 2                                 1 = Not at all aware
# 3                                 1 = Not at all aware
# 4                                 1 = Not at all aware
# ..                                                 ...
# 474                               1 = Not at all aware
# 475                               1 = Not at all aware
# 476                                 2 = Slightly aware
# 477                               1 = Not at all aware
# 478                                 3 = Somewhat aware
#
#     How supportive are you of Automatic License Plate Reader (ALPR) cameras installed by local governments and used by law enforcement? (y7ka0mc)  \
# 0                               3 = Neutral / Not sure
# 1                                  2 = Somewhat oppose
# 2                                  1 = Strongly oppose
# 3                                  1 = Strongly oppose
# 4                               3 = Neutral / Not sure
# ..                                                 ...
# 474                             3 = Neutral / Not sure
# 475                             3 = Neutral / Not sure
# 476                               5 = Strongly support
# 477                                1 = Strongly oppose
# 478                               4 = Somewhat support
#
#     How supportive are you of private individuals or businesses installing Automatic License Plate Reader (ALPR) cameras and sharing the data voluntarily with police? (uktyzgu)  \
# 0                                  2 = Somewhat oppose
# 1                               3 = Neutral / Not sure
# 2                               3 = Neutral / Not sure
# 3                                  1 = Strongly oppose
# 4                               3 = Neutral / Not sure
# ..                                                 ...
# 474                               4 = Somewhat support
# 475                                2 = Somewhat oppose
# 476                               4 = Somewhat support
# 477                                1 = Strongly oppose
# 478                               4 = Somewhat support
#
#     Have you ever felt uncomfortable or treated unfairly due to surveillance technology? (5bdjc2c)  \
# 0                                                   No
# 1                                                  Yes
# 2                                                   No
# 3                                                  Yes
# 4                                                   No
# ..                                                 ...
# 474                                                 No
# 475                                                 No
# 476                                                 No
# 477                                                 No
# 478                                           Not sure
#
#     How concerned are you that surveillance technologies may harm others (e.g., unhoused people, immigrants, protesters), even if they don’t affect you personally? (gvrrsub)  \
# 0                             3 = Moderately concerned
# 1                             3 = Moderately concerned
# 2                             3 = Moderately concerned
# 3                                   4 = Very concerned
# 4                             3 = Moderately concerned
# ..                                                 ...
# 474                                 4 = Very concerned
# 475                                 4 = Very concerned
# 476                             2 = Slightly concerned
# 477                             2 = Slightly concerned
# 478                           3 = Moderately concerned
#
#     Do you believe surveillance is being used more for public safety or social control? (cfu4j56)  \
# 0                                     3 = Equally both
# 1                        4 = Mostly for social control
# 2                      5 = Entirely for social control
# 3                      5 = Entirely for social control
# 4                                     3 = Equally both
# ..                                                 ...
# 474                                   3 = Equally both
# 475                                   3 = Equally both
# 476                       2 = Mostly for public safety
# 477                      4 = Mostly for social control
# 478                                   3 = Equally both
#
#     Which of the following groups should have access to surveillance data? (Select all that apply) (bgnrn84)  \
# 0                            Police,Federal Government
# 1           Police,Local government,Federal Government
# 2                   No one — it shouldn’t be collected
# 3                   No one — it shouldn’t be collected
# 4                                               Police
# ..                                                 ...
# 474                                             Police
# 475                                             Police
# 476         Police,Local government,Federal Government
# 477                 No one — it shouldn’t be collected
# 478               Private companies,Federal Government
#
#     Who do you trust to make decisions about how surveillance is used in your city? (Select all that apply) (w02ux9i)  \
# 0            Community organizations,Community members
# 1                                    Police department
# 2    Local elected officials,Police department,Comm...
# 3            Community organizations,Community members
# 4                                    Police department
# ..                                                 ...
# 474  Local elected officials,Community organization...
# 475          Community organizations,Community members
# 476          Local elected officials,Police department
# 477                                  Police department
# 478          Police department,Community organizations
#
#     How important is it to you that the public has input or oversight before new surveillance technologies are adopted? (ttzmqna)  \
# 0                             3 = Moderately important
# 1                             3 = Moderately important
# 2                             3 = Moderately important
# 3                                   4 = Very important
# 4                             5 = Absolutely essential
# ..                                                 ...
# 474                                 4 = Very important
# 475                           3 = Moderately important
# 476                                 4 = Very important
# 477                             2 = Slightly important
# 478                           3 = Moderately important
#
#     How likely do you think it is that police would share Automatic License Plate Reader (ALPR) data with federal agencies, even if not legally allowed? (gnnu4ft)  \
# 0                                           4 = Likely
# 1                                         2 = Unlikely
# 2                                           4 = Likely
# 3                                    1 = Very unlikely
# 4                                      5 = Very likely
# ..                                                 ...
# 474                                    5 = Very likely
# 475                                    5 = Very likely
# 476                                         3 = Unsure
# 477                                       2 = Unlikely
# 478                                         4 = Likely
#
#     It’s okay for police to track and store the location data of people who haven’t done anything wrong. (nd9oynf)  \
# 0                                2 = Somewhat disagree
# 1                                          3 = Neutral
# 2                                2 = Somewhat disagree
# 3                                1 = Strongly disagree
# 4                                1 = Strongly disagree
# ..                                                 ...
# 474                                 5 = Strongly agree
# 475                              1 = Strongly disagree
# 476                                 4 = Somewhat agree
# 477                              1 = Strongly disagree
# 478                                 4 = Somewhat agree
#
#     Surveillance technologies such as ALPRs disproportionately impact marginalized communities (e.g., by race, income, housing status, or immigration status)? (f1j1olu)  \
# 0                                   4 = Somewhat agree
# 1                                2 = Somewhat disagree
# 2                                          3 = Neutral
# 3                                1 = Strongly disagree
# 4                                          3 = Neutral
# ..                                                 ...
# 474                                 5 = Strongly agree
# 475                              2 = Somewhat disagree
# 476                              2 = Somewhat disagree
# 477                              2 = Somewhat disagree
# 478                                 4 = Somewhat agree
#
#     Surveillance technologies such as ALPRs increase public safety. (u84m4pd)  \
# 0                                   4 = Somewhat agree
# 1                                          3 = Neutral
# 2                                2 = Somewhat disagree
# 3                                          3 = Neutral
# 4                                          3 = Neutral
# ..                                                 ...
# 474                                 4 = Somewhat agree
# 475                                        3 = Neutral
# 476                                 5 = Strongly agree
# 477                                        3 = Neutral
# 478                                 4 = Somewhat agree
#
#     What should be done about ALPRs in your city? Select all that apply (vwzlz5r)  \
# 0    Require more safeguards (e.g., limits on use, ...
# 1    Require more safeguards (e.g., limits on use, ...
# 2    Reduce use,Require more safeguards (e.g., limi...
# 3          Ban them,Reduce use,Require public approval
# 4    Require more transparency,Require public appro...
# ..                                                 ...
# 474  Require more safeguards (e.g., limits on use, ...
# 475  Require more safeguards (e.g., limits on use, ...
# 476                            Keep things as they are
# 477  Reduce use,Require more safeguards (e.g., limi...
# 478  Reduce use,Require more safeguards (e.g., limi...
#
#     What is your race or ethnicity? (Select all that apply) (d8morv7)  \
# 0                                                White
# 1                            Asian or Pacific Islander
# 2                                                White
# 3                                                White
# 4                                                White
# ..                                                 ...
# 474                                 Hispanic or Latino
# 475                                 Hispanic or Latino
# 476                          Asian or Pacific Islander
# 477                                 Hispanic or Latino
# 478                          Asian or Pacific Islander
#
#     How did you find this survey? (yyxwhnl)  age  gender  \
# 0                                   Episode   22  female
# 1                              quickrewards   35  female
# 2                                    klover   23  female
# 3                                      Imvu   22  female
# 4                                      Pogo   43  female
# ..                                      ...  ...     ...
# 474  Design Home mobile game ➡️ Tap Surveys   27    male
# 475                                Attapoll   25    male
# 476                                   Email   78    male
# 477                                  Survey   45  female
# 478                                  google   37    male
#
#                                   education  yearOfBirth  educationScore  \
# 0    completedOnlyHighSchoolOrTheEquivalent         2003               2
# 1                  completedBachelorsDegree         1990               5
# 2                  completedBachelorsDegree         2002               5
# 3    completedOnlyHighSchoolOrTheEquivalent         2003               2
# 4    completedTradeTechicalVocationalTraing         1982               3
# ..                                      ...          ...             ...
# 474                completedBachelorsDegree         1998               5
# 475                completedBachelorsDegree         2000               5
# 476                completedBachelorsDegree         1947               5
# 477            completedAssociateDegreeOnly         1980               4
# 478                  completedMastersDegree         1988               6
#
#     politicalViews       householdIncome  femaleAs1MaleAs0  \
# 0         Moderate   $85,000 to $114,999               1.0
# 1         Moderate    $40,000 to $59,999               1.0
# 2     Conservative   $85,000 to $114,999               1.0
# 3         Moderate    $25,000 to $39,999               1.0
# 4     Conservative    $25,000 to $39,999               1.0
# ..             ...                   ...               ...
# 474            NaN      $200,000 or more               0.0
# 475            NaN      Less than $9,999               0.0
# 476            NaN    $40,000 to $59,999               0.0
# 477            NaN    $40,000 to $59,999               1.0
# 478            NaN  $150,000 to $199,999               0.0
#
#      politicalLiberalness  householdIncomeScore  householdIncomeEstimate  \
# 0                     0.0                     5                   100000
# 1                     0.0                     3                    50000
# 2                    -1.0                     5                   100000
# 3                     0.0                     2                    32500
# 4                    -1.0                     2                    32500
# ..                    ...                   ...                      ...
# 474                   NaN                     8                   225000
# 475                   NaN                     0                     4500
# 476                   NaN                     3                    50000
# 477                   NaN                     3                    50000
# 478                   NaN                     7                   175000
#
#     How did surveillance make you feel or impact you? (urjiu1g)  \
# 0                                                  NaN
# 1                                           no privacy
# 2                                                  NaN
# 3       It just makes me feel like they don't trust us
# 4                                                  NaN
# ..                                                 ...
# 474                                                NaN
# 475                                                NaN
# 476                                                NaN
# 477                                                NaN
# 478                                                NaN
#
#     How concerned are you about local Automatic License Plate Reader (ALPR) data being shared with federal agencies like ICE or the FBI? (izclv6s)  \
# 0                               2 = Slightly concerned
# 1                             3 = Moderately concerned
# 2                             3 = Moderately concerned
# 3                             3 = Moderately concerned
# 4                             1 = Not at all concerned
# ..                                                 ...
# 474                            5 = Extremely concerned
# 475                            5 = Extremely concerned
# 476                             2 = Slightly concerned
# 477                           1 = Not at all concerned
# 478                           3 = Moderately concerned
#
#     The San Francisco Standard recently reported that the San Francisco and Oakland Police Departments shared Automatic License Plate Reader (ALPR) data with federal agencies like ICE — in violation of state law. How concerned does this make you feel? (dgwct6r)  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 474                            5 = Extremely concerned
# 475                            5 = Extremely concerned
# 476                             2 = Slightly concerned
# 477                             2 = Slightly concerned
# 478                                 4 = Very concerned
#
#     zip_clean    zip   primary_city
# 0       59901  59901      Kalispell
# 1       91803  91803       Alhambra
# 2       30180  30180     Villa Rica
# 3       68147  68147       Bellevue
# 4       77506  77506       Pasadena
# ..        ...    ...            ...
# 474     94102  94102  San Francisco
# 475     94605  94605        Oakland
# 476     94611  94611        Oakland
# 477     94110  94110  San Francisco
# 478     94109  94109  San Francisco
#
# [479 rows x 59 columns]

# %%
df_survey = df_survey[df_survey["zip_clean"].str.startswith("9", na=False)].copy()

print("Number of CA respondents:", len(df_survey))
print("Unique CA ZIP codes:", df_survey["zip_clean"].nunique())
# Out:
# Number of CA respondents: 449
# Unique CA ZIP codes: 187

# %%
# Count how many respondents spent less than 1 minute
less_than_1 = (df_survey['Minutes Spent'] < 1).sum()
print("Number of respondents who spent <1 minute:", less_than_1)
# Out:
# Number of respondents who spent <1 minute: 6

# %%
bay_area_cities = [
    # San Francisco County
    "San Francisco",

    # Alameda County
    "Alameda","Albany","Berkeley","Dublin","Emeryville","Fremont","Hayward",
    "Livermore","Newark","Oakland","Piedmont","Pleasanton","San Leandro",
    "Union City", "Castro Valley", "San Lorenzo", "Antioch"

    # Contra Costa County
    "Antioch","Brentwood","Clayton","Concord","Danville","El Cerrito","Hercules",
    "Lafayette","Martinez","Moraga","Oakley","Orinda","Pinole","Pittsburg",
    "Pleasant Hill","Richmond","San Pablo","San Ramon","Walnut Creek",

    # Marin County
    "Belvedere","Corte Madera","Fairfax","Larkspur","Mill Valley","Novato",
    "Ross","San Anselmo","San Rafael","Sausalito","Tiburon",

    # Napa County
    "American Canyon","Calistoga","Napa","St. Helena","Yountville",

    # San Mateo County
    "Atherton","Belmont","Brisbane","Burlingame","Colma","Daly City",
    "East Palo Alto","Foster City","Half Moon Bay","Hillsborough","Menlo Park",
    "Millbrae","Pacifica","Portola Valley","Redwood City","San Bruno",
    "San Carlos","San Mateo","South San Francisco","Woodside",

    # Santa Clara County
    "Campbell","Cupertino","Gilroy","Los Altos","Los Altos Hills","Los Gatos",
    "Milpitas","Monte Sereno","Morgan Hill","Mountain View","Palo Alto",
    "San Jose","Santa Clara","Saratoga","Sunnyvale",

    # Solano County
    "Benicia","Dixon","Fairfield","Rio Vista","Suisun City","Vacaville","Vallejo",

    # Sonoma County
    "Cloverdale","Cotati","Healdsburg","Petaluma","Rohnert Park","Santa Rosa",
    "Sebastopol","Sonoma","Windsor, Forrestville",

    "Castro Valley",   # Alameda
    "San Lorenzo",     # Alameda
    "El Sobrante",     # Contra Costa
    "Discovery Bay",   # Contra Costa (CDP)  <-- note: this IS Bay Area
    "Knightsen",       # Contra Costa
    "Woodacre",        # Marin
    "Pope Valley",     # Napa
    "Guerneville",     # Sonoma
    "Forestville",     # Sonoma
    "Kenwood"
]

df_bay = df_survey[df_survey['primary_city'].isin(bay_area_cities)].copy()
df_nonbay = df_survey[~df_survey['primary_city'].isin(bay_area_cities)].copy()

print("Bay Area respondents:", len(df_bay))
print("Non-Bay Area respondents:", len(df_nonbay))
# Out:
# Bay Area respondents: 400
# Non-Bay Area respondents: 49

# %%
df_survey = df_bay.copy()

# %%
df_survey
# Out:
#           Run  Program Version  User   Time Started (UTC)  \
# 21   16220520               39   NaN  2025-08-06 09:13:01
# 22   16220528               39   NaN  2025-08-06 09:14:10
# 23   16220544               39   NaN  2025-08-06 09:20:36
# 24   16220565               39   NaN  2025-08-06 09:26:40
# 26   16220770               39   NaN  2025-08-06 10:35:06
# ..        ...              ...   ...                  ...
# 474  16646718               38   NaN  2025-09-25 15:49:19
# 475  16648785               38   NaN  2025-09-25 19:08:04
# 476  16649867               38   NaN  2025-09-25 21:09:28
# 477  16658812               38   NaN  2025-09-26 15:39:27
# 478  16658980               38   NaN  2025-09-26 15:53:27
#
#      Time Finished (UTC)  Minutes Spent Position  Points  \
# 21                   NaN           3.55  7h99xur       0
# 22                   NaN           2.83  7h99xur       0
# 23                   NaN           5.45  7h99xur       0
# 24                   NaN           4.55  7h99xur       0
# 26                   NaN           2.93  7h99xur       0
# ..                   ...            ...      ...     ...
# 474                  NaN           8.63  7h99xur       0
# 475                  NaN           5.15  7h99xur       0
# 476                  NaN           5.55  7h99xur       0
# 477                  NaN           3.62  7h99xur       0
# 478                  NaN           1.35  7h99xur       0
#
#      testing question? (8vufenf)  \
# 21                           NaN
# 22                           NaN
# 23                           NaN
# 24                           NaN
# 26                           NaN
# ..                           ...
# 474                          NaN
# 475                          NaN
# 476                          NaN
# 477                          NaN
# 478                          NaN
#
#     Have you noticed surveillance technologies in your neighborhood that were installed by the government, police, or private businesses (not personal home cameras like Ring or Nest)? (lw3083d)  \
# 21                                                 Yes
# 22                                                  No
# 23                                                 Yes
# 24                                                 Yes
# 26                                                 Yes
# ..                                                 ...
# 474                                                Yes
# 475                                                Yes
# 476                                           Not sure
# 477                                                 No
# 478                                                Yes
#
#     What is your ZIP code? (7bepp7b) participantID assignmentID  projectID  \
# 21                             94561     pce548793    pc5fc5d14  pffe2652f
# 22                             94578     pa4c058f8    pdb5095ed  pffe2652f
# 23                             94611     pdd2f93b7    pf32c27ed  pffe2652f
# 24                             94122     pa456f7a3    pb748be71  pffe2652f
# 26                             94026     pfa30393c    pfc2ec94d  pffe2652f
# ..                               ...           ...          ...        ...
# 474                            94102     pf59512b9    pdd5471fa  pffe2652f
# 475                            94605     pcbfa4b18    pbed380dd  pffe2652f
# 476                            94611     pd4a54585    pabced9de  pffe2652f
# 477                            94110     pfa932d74    pd383af85  pffe2652f
# 478                            94109     pfb1ff4c5    pf0c4fd65  pffe2652f
#
#                startedAt computerCountry  \
# 21   2025/08/06 02:11 AM   United States
# 22   2025/08/06 02:12 AM   United States
# 23   2025/08/06 02:18 AM   United States
# 24   2025/08/06 02:22 AM   United States
# 26   2025/08/06 03:33 AM   United States
# ..                   ...             ...
# 474  2025/09/25 08:45 AM   United States
# 475  2025/09/25 12:04 PM   United States
# 476  2025/09/25 02:08 PM   United States
# 477  2025/09/26 08:37 AM   United States
# 478  2025/09/26 08:52 AM   United States
#
#                                    computerID      device  \
# 21   6a31ea14d477d58c3f0019f14ac3f38267989a1b  smartphone
# 22   9d9e9a916aae473797c6c2f720a1f801ceb6928b  smartphone
# 23   39590f204b944aa4bc4f83168bb192f0d6ed1c96  smartphone
# 24   b1ba0baea0458f599bfc21868195d2d04ec39b1f  smartphone
# 26   ab39f2662a7a1bbab2ff6c24f3141422f698e8c6  smartphone
# ..                                        ...         ...
# 474  459187c95ac0b8d58cc128809f199ec576baf980  smartphone
# 475  0f358509ddf66d953fc79fea6ed1c422654ed76f  smartphone
# 476  bbba5821dea8d68471e1f36b535706ef2dc9f94c     desktop
# 477  c9ec7009d852cf69727aac31a1d7faa4b41f0003  smartphone
# 478  b6a27eefd7e820be0b2b2bdb37db27058021f364     desktop
#
#     Which of the following surveillance tools have you heard of or seen in your city? (Select all that apply) (8dl9hmt)  \
# 21         Surveillance/security cameras,Speed Cameras
# 22                                   None of the above
# 23   Surveillance/security cameras,Automatic Licens...
# 24   Surveillance/security cameras,Drones,Facial re...
# 26   Surveillance/security cameras,ShotSpotter or g...
# ..                                                 ...
# 474        Surveillance/security cameras,Speed Cameras
# 475  Surveillance/security cameras,Drones,Facial re...
# 476  Surveillance/security cameras,Automatic Licens...
# 477  Automatic License Plate Readers (ALPRs),Speed ...
# 478  Surveillance/security cameras,Automatic Licens...
#
#     How concerned are you about surveillance technology in public spaces like streets, sidewalks, or public transit? (n15scu9)  \
# 21                            1 = Not at all concerned
# 22                            1 = Not at all concerned
# 23                            3 = Moderately concerned
# 24                            3 = Moderately concerned
# 26                            3 = Moderately concerned
# ..                                                 ...
# 474                           3 = Moderately concerned
# 475                           3 = Moderately concerned
# 476                           1 = Not at all concerned
# 477                             2 = Slightly concerned
# 478                           3 = Moderately concerned
#
#     How often do you notice surveillance cameras or sensors in your neighborhood or daily routine? (6itkmu)  \
# 21                                           4 = Often
# 22                                       3 = Sometimes
# 23                                    5 = All the time
# 24                                    5 = All the time
# 26                                       3 = Sometimes
# ..                                                 ...
# 474                                      3 = Sometimes
# 475                                      3 = Sometimes
# 476                                          1 = Never
# 477                                      3 = Sometimes
# 478                                      3 = Sometimes
#
#     How familiar are you with how automatic license plate reader (ALPR) cameras work? (724al0n)  \
# 21                             1 = Not at all familiar
# 22                               3 = Somewhat familiar
# 23                               3 = Somewhat familiar
# 24                               3 = Somewhat familiar
# 26                             1 = Not at all familiar
# ..                                                 ...
# 474                                  4 = Very familiar
# 475                              2 = Slightly familiar
# 476                              3 = Somewhat familiar
# 477                            1 = Not at all familiar
# 478                              3 = Somewhat familiar
#
#     After being approved by local governments, private companies like Flock Safety install Automatic License Plate Reader (ALPR) cameras in neighborhoods and share data with police. Before today, how aware were you of that fact? (50mnfkf)  \
# 21                                1 = Not at all aware
# 22                                  3 = Somewhat aware
# 23                                      4 = Very aware
# 24                                  3 = Somewhat aware
# 26                                  3 = Somewhat aware
# ..                                                 ...
# 474                                 3 = Somewhat aware
# 475                                 2 = Slightly aware
# 476                               1 = Not at all aware
# 477                               1 = Not at all aware
# 478                                 3 = Somewhat aware
#
#     In some Bay Area cities, Automatic License Plate Reader (ALPR) cameras store an image of your license plate, vehicle make and model, and location in a searchable database for up to 12 months every time you drive past one. Before today, how aware were you of that fact? (6s6r3ex)  \
# 21                                  2 = Slightly aware
# 22                                      4 = Very aware
# 23                                  2 = Slightly aware
# 24                                      4 = Very aware
# 26                                  3 = Somewhat aware
# ..                                                 ...
# 474                               1 = Not at all aware
# 475                                 2 = Slightly aware
# 476                                     4 = Very aware
# 477                               1 = Not at all aware
# 478                                 3 = Somewhat aware
#
#     Police can search the Automatic License Plate Reader (ALPR) database for your data without a warrant or approval from any other organization. Before today, how aware were you of that fact? (zke2ete)  \
# 21                                  2 = Slightly aware
# 22                                      4 = Very aware
# 23                                1 = Not at all aware
# 24                                  3 = Somewhat aware
# 26                                  2 = Slightly aware
# ..                                                 ...
# 474                               1 = Not at all aware
# 475                                 2 = Slightly aware
# 476                                 2 = Slightly aware
# 477                               1 = Not at all aware
# 478                                 3 = Somewhat aware
#
#     Police can legally share your license plate Automatic License Plate Reader (ALPR) data with other local governments/police departments within California at any time without a warrant. Before today, how aware were you of that fact? (skzr4a8)  \
# 21                                  3 = Somewhat aware
# 22                                  3 = Somewhat aware
# 23                                      4 = Very aware
# 24                                  2 = Slightly aware
# 26                                  3 = Somewhat aware
# ..                                                 ...
# 474                                 2 = Slightly aware
# 475                                 2 = Slightly aware
# 476                                 3 = Somewhat aware
# 477                                 2 = Slightly aware
# 478                                 3 = Somewhat aware
#
#     The image above shows locations and number of Automatic License Plate Reader (ALPR) cameras in the Bay Area reported by residents. Actual locations and counts may vary, but there is likely to be more installed than shown in the image. Before today, how aware were you of the number of ALPR cameras in the Bay Area? (3eg0nl6)  \
# 21                                  2 = Slightly aware
# 22                                1 = Not at all aware
# 23                                1 = Not at all aware
# 24                                1 = Not at all aware
# 26                                  3 = Somewhat aware
# ..                                                 ...
# 474                               1 = Not at all aware
# 475                               1 = Not at all aware
# 476                                 2 = Slightly aware
# 477                               1 = Not at all aware
# 478                                 3 = Somewhat aware
#
#     How supportive are you of Automatic License Plate Reader (ALPR) cameras installed by local governments and used by law enforcement? (y7ka0mc)  \
# 21                              3 = Neutral / Not sure
# 22                                 2 = Somewhat oppose
# 23                                 2 = Somewhat oppose
# 24                                5 = Strongly support
# 26                              3 = Neutral / Not sure
# ..                                                 ...
# 474                             3 = Neutral / Not sure
# 475                             3 = Neutral / Not sure
# 476                               5 = Strongly support
# 477                                1 = Strongly oppose
# 478                               4 = Somewhat support
#
#     How supportive are you of private individuals or businesses installing Automatic License Plate Reader (ALPR) cameras and sharing the data voluntarily with police? (uktyzgu)  \
# 21                                 2 = Somewhat oppose
# 22                                 2 = Somewhat oppose
# 23                                 1 = Strongly oppose
# 24                              3 = Neutral / Not sure
# 26                              3 = Neutral / Not sure
# ..                                                 ...
# 474                               4 = Somewhat support
# 475                                2 = Somewhat oppose
# 476                               4 = Somewhat support
# 477                                1 = Strongly oppose
# 478                               4 = Somewhat support
#
#     Have you ever felt uncomfortable or treated unfairly due to surveillance technology? (5bdjc2c)  \
# 21                                                  No
# 22                                                  No
# 23                                                 Yes
# 24                                                  No
# 26                                                  No
# ..                                                 ...
# 474                                                 No
# 475                                                 No
# 476                                                 No
# 477                                                 No
# 478                                           Not sure
#
#     How concerned are you that surveillance technologies may harm others (e.g., unhoused people, immigrants, protesters), even if they don’t affect you personally? (gvrrsub)  \
# 21                              2 = Slightly concerned
# 22                            3 = Moderately concerned
# 23                                  4 = Very concerned
# 24                                  4 = Very concerned
# 26                            3 = Moderately concerned
# ..                                                 ...
# 474                                 4 = Very concerned
# 475                                 4 = Very concerned
# 476                             2 = Slightly concerned
# 477                             2 = Slightly concerned
# 478                           3 = Moderately concerned
#
#     Do you believe surveillance is being used more for public safety or social control? (cfu4j56)  \
# 21                                    3 = Equally both
# 22                                    3 = Equally both
# 23                       4 = Mostly for social control
# 24                      1 = Entirely for public safety
# 26                                    3 = Equally both
# ..                                                 ...
# 474                                   3 = Equally both
# 475                                   3 = Equally both
# 476                       2 = Mostly for public safety
# 477                      4 = Mostly for social control
# 478                                   3 = Equally both
#
#     Which of the following groups should have access to surveillance data? (Select all that apply) (bgnrn84)  \
# 21                 Local government,Federal Government
# 22          Police,Local government,Federal Government
# 23                  No one — it shouldn’t be collected
# 24                                              Police
# 26                  No one — it shouldn’t be collected
# ..                                                 ...
# 474                                             Police
# 475                                             Police
# 476         Police,Local government,Federal Government
# 477                 No one — it shouldn’t be collected
# 478               Private companies,Federal Government
#
#     Who do you trust to make decisions about how surveillance is used in your city? (Select all that apply) (w02ux9i)  \
# 21                                   Police department
# 22   Local elected officials,Police department,Comm...
# 23           Community organizations,Community members
# 24                 Police department,Community members
# 26                                             Marines
# ..                                                 ...
# 474  Local elected officials,Community organization...
# 475          Community organizations,Community members
# 476          Local elected officials,Police department
# 477                                  Police department
# 478          Police department,Community organizations
#
#     How important is it to you that the public has input or oversight before new surveillance technologies are adopted? (ttzmqna)  \
# 21                              2 = Slightly important
# 22                            3 = Moderately important
# 23                            5 = Absolutely essential
# 24                                  4 = Very important
# 26                            3 = Moderately important
# ..                                                 ...
# 474                                 4 = Very important
# 475                           3 = Moderately important
# 476                                 4 = Very important
# 477                             2 = Slightly important
# 478                           3 = Moderately important
#
#     How likely do you think it is that police would share Automatic License Plate Reader (ALPR) data with federal agencies, even if not legally allowed? (gnnu4ft)  \
# 21                                        2 = Unlikely
# 22                                          3 = Unsure
# 23                                          3 = Unsure
# 24                                        2 = Unlikely
# 26                                          3 = Unsure
# ..                                                 ...
# 474                                    5 = Very likely
# 475                                    5 = Very likely
# 476                                         3 = Unsure
# 477                                       2 = Unlikely
# 478                                         4 = Likely
#
#     It’s okay for police to track and store the location data of people who haven’t done anything wrong. (nd9oynf)  \
# 21                               1 = Strongly disagree
# 22                                         3 = Neutral
# 23                               1 = Strongly disagree
# 24                               1 = Strongly disagree
# 26                                         3 = Neutral
# ..                                                 ...
# 474                                 5 = Strongly agree
# 475                              1 = Strongly disagree
# 476                                 4 = Somewhat agree
# 477                              1 = Strongly disagree
# 478                                 4 = Somewhat agree
#
#     Surveillance technologies such as ALPRs disproportionately impact marginalized communities (e.g., by race, income, housing status, or immigration status)? (f1j1olu)  \
# 21                               2 = Somewhat disagree
# 22                                         3 = Neutral
# 23                               1 = Strongly disagree
# 24                                         3 = Neutral
# 26                                         3 = Neutral
# ..                                                 ...
# 474                                 5 = Strongly agree
# 475                              2 = Somewhat disagree
# 476                              2 = Somewhat disagree
# 477                              2 = Somewhat disagree
# 478                                 4 = Somewhat agree
#
#     Surveillance technologies such as ALPRs increase public safety. (u84m4pd)  \
# 21                                  4 = Somewhat agree
# 22                                         3 = Neutral
# 23                                         3 = Neutral
# 24                                  4 = Somewhat agree
# 26                                         3 = Neutral
# ..                                                 ...
# 474                                 4 = Somewhat agree
# 475                                        3 = Neutral
# 476                                 5 = Strongly agree
# 477                                        3 = Neutral
# 478                                 4 = Somewhat agree
#
#     What should be done about ALPRs in your city? Select all that apply (vwzlz5r)  \
# 21                             Require public approval
# 22   Require more safeguards (e.g., limits on use, ...
# 23   Reduce use,Require more safeguards (e.g., limi...
# 24   Require more safeguards (e.g., limits on use, ...
# 26                           Require more transparency
# ..                                                 ...
# 474  Require more safeguards (e.g., limits on use, ...
# 475  Require more safeguards (e.g., limits on use, ...
# 476                            Keep things as they are
# 477  Reduce use,Require more safeguards (e.g., limi...
# 478  Reduce use,Require more safeguards (e.g., limi...
#
#     What is your race or ethnicity? (Select all that apply) (d8morv7)  \
# 21                                                 NaN
# 22                                  Hispanic or Latino
# 23                           Black or African American
# 24                                               White
# 26                                  Hispanic or Latino
# ..                                                 ...
# 474                                 Hispanic or Latino
# 475                                 Hispanic or Latino
# 476                          Asian or Pacific Islander
# 477                                 Hispanic or Latino
# 478                          Asian or Pacific Islander
#
#     How did you find this survey? (yyxwhnl)  age  gender  \
# 21                                   Tiktok   19  female
# 22                                  Positly   20  female
# 23                                   Friend   34    male
# 24                                  Positly   30  female
# 26                            Survey junkie   45    male
# ..                                      ...  ...     ...
# 474  Design Home mobile game ➡️ Tap Surveys   27    male
# 475                                Attapoll   25    male
# 476                                   Email   78    male
# 477                                  Survey   45  female
# 478                                  google   37    male
#
#                                   education  yearOfBirth  educationScore  \
# 21   completedOnlyHighSchoolOrTheEquivalent         2006               2
# 22   completedOnlyHighSchoolOrTheEquivalent         2005               2
# 23                 completedBachelorsDegree         1991               5
# 24                   completedMastersDegree         1995               6
# 26   completedTradeTechicalVocationalTraing         1980               3
# ..                                      ...          ...             ...
# 474                completedBachelorsDegree         1998               5
# 475                completedBachelorsDegree         2000               5
# 476                completedBachelorsDegree         1947               5
# 477            completedAssociateDegreeOnly         1980               4
# 478                  completedMastersDegree         1988               6
#
#     politicalViews       householdIncome  femaleAs1MaleAs0  \
# 21        Moderate      Less than $9,999               1.0
# 22        Moderate      Less than $9,999               1.0
# 23        Moderate  $115,000 to $149,999               0.0
# 24        Moderate  $150,000 to $199,999               1.0
# 26        Moderate    $10,000 to $24,999               0.0
# ..             ...                   ...               ...
# 474            NaN      $200,000 or more               0.0
# 475            NaN      Less than $9,999               0.0
# 476            NaN    $40,000 to $59,999               0.0
# 477            NaN    $40,000 to $59,999               1.0
# 478            NaN  $150,000 to $199,999               0.0
#
#      politicalLiberalness  householdIncomeScore  householdIncomeEstimate  \
# 21                    0.0                     0                     4500
# 22                    0.0                     0                     4500
# 23                    0.0                     6                   132500
# 24                    0.0                     7                   175000
# 26                    0.0                     1                    17500
# ..                    ...                   ...                      ...
# 474                   NaN                     8                   225000
# 475                   NaN                     0                     4500
# 476                   NaN                     3                    50000
# 477                   NaN                     3                    50000
# 478                   NaN                     7                   175000
#
#     How did surveillance make you feel or impact you? (urjiu1g)  \
# 21                                                 NaN
# 22                                                 NaN
# 23   I know I’m being watched by a neighbor and I d...
# 24                                                 NaN
# 26                                                 NaN
# ..                                                 ...
# 474                                                NaN
# 475                                                NaN
# 476                                                NaN
# 477                                                NaN
# 478                                                NaN
#
#     How concerned are you about local Automatic License Plate Reader (ALPR) data being shared with federal agencies like ICE or the FBI? (izclv6s)  \
# 21                            3 = Moderately concerned
# 22                             5 = Extremely concerned
# 23                            3 = Moderately concerned
# 24                            3 = Moderately concerned
# 26                              2 = Slightly concerned
# ..                                                 ...
# 474                            5 = Extremely concerned
# 475                            5 = Extremely concerned
# 476                             2 = Slightly concerned
# 477                           1 = Not at all concerned
# 478                           3 = Moderately concerned
#
#     The San Francisco Standard recently reported that the San Francisco and Oakland Police Departments shared Automatic License Plate Reader (ALPR) data with federal agencies like ICE — in violation of state law. How concerned does this make you feel? (dgwct6r)  \
# 21                              2 = Slightly concerned
# 22                            3 = Moderately concerned
# 23                                  4 = Very concerned
# 24                             5 = Extremely concerned
# 26                            3 = Moderately concerned
# ..                                                 ...
# 474                            5 = Extremely concerned
# 475                            5 = Extremely concerned
# 476                             2 = Slightly concerned
# 477                             2 = Slightly concerned
# 478                                 4 = Very concerned
#
#     zip_clean    zip   primary_city
# 21      94561  94561         Oakley
# 22      94578  94578    San Leandro
# 23      94611  94611        Oakland
# 24      94122  94122  San Francisco
# 26      94026  94026     Menlo Park
# ..        ...    ...            ...
# 474     94102  94102  San Francisco
# 475     94605  94605        Oakland
# 476     94611  94611        Oakland
# 477     94110  94110  San Francisco
# 478     94109  94109  San Francisco
#
# [400 rows x 59 columns]

# %%
df_bay.to_csv('output_data.csv', index=False)

# %%
df_nonbay['primary_city'].unique()
# Out:
# array(['Alhambra', 'Bakersfield', 'Sacramento', 'Los Angeles',
#        'Brookings', 'Watsonville', 'Davis', 'Lodi', 'Stockton', 'Tracy',
#        'Los Banos', 'Newman', 'Portland', 'Hollister', 'Antioch',
#        'Rancho Cordova', 'Tustin', 'Windsor', 'Boulder Creek', 'Castaic',
#        'Lower Lake', 'Santa Cruz', 'Honolulu', 'Inglewood'], dtype=object)

# %%
# count of which rows are not nans
not_nan_count = df_survey['How did surveillance make you feel or impact you? (urjiu1g)'].notna().sum()
print(not_nan_count)
# Out:
# 88

# %%
df_survey.columns
# Out:
# Index(['Run', 'Program Version', 'User', 'Time Started (UTC)',
#        'Time Finished (UTC)', 'Minutes Spent', 'Position', 'Points',
#        'testing question? (8vufenf)',
#        'Have you noticed surveillance technologies in your neighborhood that were installed by the government, police, or private businesses (not personal home cameras like Ring or Nest)? (lw3083d)',
#        'What is your ZIP code? (7bepp7b)', 'participantID', 'assignmentID',
#        'projectID', 'startedAt', 'computerCountry', 'computerID', 'device',
#        'Which of the following surveillance tools have you heard of or seen in your city? (Select all that apply) (8dl9hmt)',
#        'How concerned are you about surveillance technology in public spaces like streets, sidewalks, or public transit? (n15scu9)',
#        'How often do you notice surveillance cameras or sensors in your neighborhood or daily routine? (6itkmu)',
#        'How familiar are you with how automatic license plate reader (ALPR) cameras work? (724al0n)',
#        'After being approved by local governments, private companies like Flock Safety install Automatic License Plate Reader (ALPR) cameras in neighborhoods and share data with police. Before today, how aware were you of that fact? (50mnfkf)',
#        'In some Bay Area cities, Automatic License Plate Reader (ALPR) cameras store an image of your license plate, vehicle make and model, and location in a searchable database for up to 12 months every time you drive past one. Before today, how aware were you of that fact? (6s6r3ex)',
#        'Police can search the Automatic License Plate Reader (ALPR) database for your data without a warrant or approval from any other organization. Before today, how aware were you of that fact? (zke2ete)',
#        'Police can legally share your license plate Automatic License Plate Reader (ALPR) data with other local governments/police departments within California at any time without a warrant. Before today, how aware were you of that fact? (skzr4a8)',
#        'The image above shows locations and number of Automatic License Plate Reader (ALPR) cameras in the Bay Area reported by residents. Actual locations and counts may vary, but there is likely to be more installed than shown in the image. Before today, how aware were you of the number of ALPR cameras in the Bay Area? (3eg0nl6)',
#        'How supportive are you of Automatic License Plate Reader (ALPR) cameras installed by local governments and used by law enforcement? (y7ka0mc)',
#        'How supportive are you of private individuals or businesses installing Automatic License Plate Reader (ALPR) cameras and sharing the data voluntarily with police? (uktyzgu)',
#        'Have you ever felt uncomfortable or treated unfairly due to surveillance technology? (5bdjc2c)',
#        'How concerned are you that surveillance technologies may harm others (e.g., unhoused people, immigrants, protesters), even if they don’t affect you personally? (gvrrsub)',
#        'Do you believe surveillance is being used more for public safety or social control? (cfu4j56)',
#        'Which of the following groups should have access to surveillance data? (Select all that apply) (bgnrn84)',
#        'Who do you trust to make decisions about how surveillance is used in your city? (Select all that apply) (w02ux9i)',
#        'How important is it to you that the public has input or oversight before new surveillance technologies are adopted? (ttzmqna)',
#        'How likely do you think it is that police would share Automatic License Plate Reader (ALPR) data with federal agencies, even if not legally allowed? (gnnu4ft)',
#        'It’s okay for police to track and store the location data of people who haven’t done anything wrong. (nd9oynf)',
#        'Surveillance technologies such as ALPRs disproportionately impact marginalized communities (e.g., by race, income, housing status, or immigration status)? (f1j1olu)',
#        'Surveillance technologies such as ALPRs increase public safety. (u84m4pd)',
#        'What should be done about ALPRs in your city? Select all that apply (vwzlz5r)',
#        'What is your race or ethnicity? (Select all that apply) (d8morv7)',
#        'How did you find this survey? (yyxwhnl)', 'age', 'gender', 'education',
#        'yearOfBirth', 'educationScore', 'politicalViews', 'householdIncome',
#        'femaleAs1MaleAs0', 'politicalLiberalness', 'householdIncomeScore',
#        'householdIncomeEstimate',
#        'How did surveillance make you feel or impact you? (urjiu1g)',
#        'How concerned are you about local Automatic License Plate Reader (ALPR) data being shared with federal agencies like ICE or the FBI? (izclv6s)',
#        'The San Francisco Standard recently reported that the San Francisco and Oakland Police Departments shared Automatic License Plate Reader (ALPR) data with federal agencies like ICE — in violation of state law. How concerned does this make you feel? (dgwct6r)',
#        'zip_clean', 'zip', 'primary_city'],
#       dtype='object')

# %%
# Do people who support ALPRs believe they can harm certain marginalized groups?

# Fix long title lol
df = df_survey.rename(columns={
    'How supportive are you of Automatic License Plate Reader (ALPR) cameras installed by local governments and used by law enforcement? (y7ka0mc)': 'support_gov',
    'How supportive are you of private individuals or businesses installing Automatic License Plate Reader (ALPR) cameras and sharing the data voluntarily with police? (uktyzgu)': 'support_private',
    'Surveillance technologies such as ALPRs disproportionately impact marginalized communities (e.g., by race, income, housing status, or immigration status)? (f1j1olu)': 'harm_belief',
    'How concerned are you that surveillance technologies may harm others (e.g., unhoused people, immigrants, protesters), even if they don’t affect you personally? (gvrrsub)': 'concern_others'
})

# List of columns
cols = ['support_gov', 'support_private', 'harm_belief', 'concern_others']

# Unique vals
for col in cols:
    print(f"\nUnique values in {col}:")
    print(df[col].unique())
# Out:
# Unique values in support_gov:
# ['3 = Neutral / Not sure' '2 = Somewhat oppose' '5 = Strongly support'
#  '4 = Somewhat support' '1 = Strongly oppose']
#
# Unique values in support_private:
# ['2 = Somewhat oppose' '1 = Strongly oppose' '3 = Neutral / Not sure'
#  '5 = Strongly support' '4 = Somewhat support']
#
# Unique values in harm_belief:
# ['2 = Somewhat disagree' '3 = Neutral' '1 = Strongly disagree'
#  '5 = Strongly agree' '4 = Somewhat agree']
#
# Unique values in concern_others:
# ['2 = Slightly concerned' '3 = Moderately concerned' '4 = Very concerned'
#  '1 = Not concerned at all' '5 = Extremely concerned']

# %%
# NAN count
nan_counts = df[cols].isna().sum()
non_nan_counts = df[cols].notna().sum()

# View
summary = pd.DataFrame({
    'Non-NaN Count': non_nan_counts,
    'NaN Count': nan_counts
})

print(summary)
# Out:
#                  Non-NaN Count  NaN Count
# support_gov                400          0
# support_private            400          0
# harm_belief                400          0
# concern_others             400          0

# %%
# Remove NaNs
df = df.dropna(subset=cols)

# %%
def extract_numeric(val):
    if pd.isna(val):
        return None
    return int(str(val).split('=')[0].strip())

for col in ['support_gov', 'support_private', 'harm_belief', 'concern_others']:
    df[col + '_num'] = df[col].apply(extract_numeric)

# %%
df = df[
    df['support_gov_num'].between(1, 5) &
    df['harm_belief_num'].between(1, 5)
]

# %%
plt.rcParams['axes.grid'] = False
plt.rcParams['patch.edgecolor'] = 'none'

# %%
ct = pd.crosstab(df['support_gov_num'], df['harm_belief_num'], normalize='index')

# Plot
ax = ct.plot(kind='bar', stacked=True, cmap='OrRd', figsize=(8, 5))
ax.set_title("Support for Gov ALPRs vs Harm Belief")
ax.set_xlabel("Gov ALPR Support (1 = Oppose … 5 = Support)")
ax.set_ylabel("Proportion of Respondents")
ax.legend(title="Harm Belief", bbox_to_anchor=(1.05, 1))
plt.tight_layout()
plt.show()

# %%
ct = pd.crosstab(df['support_gov_num'], df['concern_others'], normalize='index')

# Plot
ax = ct.plot(kind='bar', stacked=True, cmap='OrRd', figsize=(8, 5))
ax.set_title("Support for Gov ALPRs vs Concern for Others")
ax.set_xlabel("Gov ALPR Support (1 = Oppose … 5 = Support)")
ax.set_ylabel("Proportion of Respondents")
ax.legend(title="Concern for Others", bbox_to_anchor=(1.05, 1))
plt.tight_layout()
plt.show()

# %%
# Crosstab and plot for private ALPRs vs harm_belief
ct = pd.crosstab(df['support_private_num'], df['harm_belief_num'], normalize='index')
ct.plot(kind='bar', stacked=True, cmap='OrRd')
plt.title("Support for Private ALPRs vs Harm Belief")
plt.xlabel("Private ALPR Support (1 = Oppose … 5 = Support)")
plt.ylabel("Proportion of Respondents")
plt.legend(title="Harm Belief", bbox_to_anchor=(1.05, 1))
plt.tight_layout()
plt.show()

# %%
ct = pd.crosstab(df['support_private_num'], df['concern_others'], normalize='index')

ax = ct.plot(kind='bar', stacked=True, cmap='OrRd', figsize=(8, 5))
ax.set_title("Support for Private ALPRs vs Concern for Others")
ax.set_xlabel("Private ALPR Support (1 = Oppose … 5 = Support)")
ax.set_ylabel("Proportion of Respondents")
ax.legend(title="Concern for Others", bbox_to_anchor=(1.05, 1))
plt.tight_layout()
plt.show()

# %%
ct = pd.crosstab(df['support_gov_num'], df['concern_others'], normalize='index')

ax = ct.plot(kind='bar', stacked=True, cmap='OrRd', figsize=(8, 5))
ax.set_title("Support for Gov ALPRs vs Concern for Others")
ax.set_xlabel("Gov ALPR Support (1 = Oppose … 5 = Support)")
ax.set_ylabel("Proportion of Respondents")
ax.legend(title="Concern for Others", bbox_to_anchor=(1.05, 1))
plt.tight_layout()
plt.show()

# %%
ct = pd.crosstab(df['support_gov_num'], df['harm_belief_num'], normalize='index')

harm_belief_labels = {
    1: '1 = Strongly disagree',
    2: '2 = Somewhat disagree',
    3: '3 = Neutral',
    4: '4 = Somewhat agree',
    5: '5 = Strongly agree'
}

ct.columns = [harm_belief_labels.get(col, str(col)) for col in ct.columns]

ax = ct.plot(kind='bar', stacked=True, cmap='OrRd', figsize=(8, 5))
ax.set_title("Support for Gov ALPRs vs Harm Belief")
ax.set_xlabel("Gov ALPR Support (1 = Oppose … 5 = Support)")
ax.set_ylabel("Proportion of Respondents")
ax.legend(title="Harm Belief", bbox_to_anchor=(1.05, 1))
plt.tight_layout()
plt.show()

# %%
ct = pd.crosstab(df['support_private_num'], df['harm_belief_num'], normalize='index')

harm_belief_labels = {
    1: '1 = Strongly disagree',
    2: '2 = Somewhat disagree',
    3: '3 = Neutral',
    4: '4 = Somewhat agree',
    5: '5 = Strongly agree'
}

ct.columns = [harm_belief_labels.get(col, str(col)) for col in ct.columns]

ax = ct.plot(kind='bar', stacked=True, cmap='OrRd', figsize=(8, 5))
ax.set_title("Support for Private ALPRs vs Harm Belief")
ax.set_xlabel("Private ALPR Support (1 = Oppose … 5 = Support)")
ax.set_ylabel("Proportion of Respondents")
ax.legend(title="Harm Belief", bbox_to_anchor=(1.05, 1))
plt.tight_layout()
plt.show()

# %%
sns.stripplot(
    x='support_gov_num',
    y='support_private_num',
    data=df,
    jitter=0.3,
    alpha=0.6,
    palette='OrRd'
)
plt.xlabel("Gov ALPR Support (1 = Oppose … 5 = Support)")
plt.ylabel("Private ALPR Support (1 = Oppose … 5 = Support)")
plt.title("Support for Gov vs Private ALPRs")
plt.show()
# Out:
# /tmp/ipython-input-4227996433.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(

# %%
df['support_diff'] = df['support_gov_num'] - df['support_private_num']

print(df['support_diff'].value_counts().sort_index())
# Out:
# support_diff
# -3      3
# -2     12
# -1     34
#  0    216
#  1     98
#  2     33
#  3      4
# Name: count, dtype: int64

# %%
# Create binary columns for race/ethnicity
race_dummies = df['What is your race or ethnicity? (Select all that apply) (d8morv7)'].str.get_dummies(sep=', ')
race_dummies.columns = ['race_' + col.strip().replace(" ", "_").replace("/", "_") for col in race_dummies.columns]
df = pd.concat([df, race_dummies], axis=1)

# %%
df.groupby('gender')[['support_gov_num', 'support_private_num', 'harm_belief_num', 'concern_others_num']].mean()
# Out:
#         support_gov_num  support_private_num  harm_belief_num  \
# gender
# female         2.889952              2.62201         3.583732
# male           3.068421              2.80000         3.400000
# other          3.000000              1.00000         4.000000
#
#         concern_others_num
# gender
# female            3.076555
# male              2.905263
# other             4.000000

# %%
df.groupby('race_White')[['support_gov_num', 'harm_belief_num']].mean()
# Out:
#             support_gov_num  harm_belief_num
# race_White
# 0                  2.912052         3.524430
# 1                  3.182796         3.408602

# %%
# Demographic columns
cat_cols = [
    'gender',
    'education',
    'politicalViews',
    'What is your race or ethnicity? (Select all that apply) (d8morv7)',
]

# Unique vals
for col in cat_cols:
    print(f"\nUnique values in '{col}':")
    print(df[col].dropna().unique())
# Out:
# Unique values in 'gender':
# ['female' 'male' 'other']
#
# Unique values in 'education':
# ['completedOnlyHighSchoolOrTheEquivalent' 'completedBachelorsDegree'
#  'completedMastersDegree' 'completedTradeTechicalVocationalTraing'
#  'completedProfessionalDegree' 'completedAssociateDegreeOnly'
#  'completedDoctorateDegree' 'nurseryTo8thGrade'
#  'noSchoolingAtAllCompleted']
#
# Unique values in 'politicalViews':
# ['Moderate' 'Liberal' 'Very conservative' 'Conservative' 'Very liberal']
#
# Unique values in 'What is your race or ethnicity? (Select all that apply) (d8morv7)':
# ['Hispanic or Latino' 'Black or African American' 'White'
#  'Black or African American,Native American or Indigenous,White'
#  'Asian or Pacific Islander'
#  'Hispanic or Latino,White,Middle Eastern or North African'
#  'Native American or Indigenous' 'Prefer not to say'
#  'Hispanic or Latino,Asian or Pacific Islander' 'Hispanic or Latino,White'
#  'Another race or ethnicity' 'Asian or Pacific Islander,White'
#  'Black or African American,Asian or Pacific Islander'
#  'Middle Eastern or North African'
#  'Black or African American,Hispanic or Latino,White'
#  'Native American or Indigenous,White'
#  'Hispanic or Latino,Asian or Pacific Islander,White'
#  'Black or African American,White'
#  'Black or African American,Hispanic or Latino'
#  'Asian or Pacific Islander,Prefer not to say'
#  'Asian or Pacific Islander,Native American or Indigenous'
#  'Black or African American,White,Another race or ethnicity'
#  'Asian or Pacific Islander,White,Middle Eastern or North African'
#  'Asian or Pacific Islander,White,Another race or ethnicity'
#  'White,Middle Eastern or North African'
#  'Hispanic or Latino,Native American or Indigenous']

# %%
df['gender_female'] = (df['gender'] == 'female').astype(int)
df['gender_other'] = (df['gender'] == 'other').astype(int)

# %%
edu_map = {
    'noSchoolingAtAllCompleted': 0,
    'nurseryTo8thGrade': 1,
    'completedOnlyHighSchoolOrTheEquivalent': 2,
    'completedTradeTechicalVocationalTraing': 3,
    'completedAssociateDegreeOnly': 4,
    'completedBachelorsDegree': 5,
    'completedMastersDegree': 6,
    'completedProfessionalDegree': 7,
    'completedDoctorateDegree': 8
}
df['education_ord'] = df['education'].map(edu_map)

# %%
pol_map = {
    'Very conservative': 1,
    'Conservative': 2,
    'Moderate': 3,
    'Liberal': 4,
    'Very liberal': 5
}
df['political_ord'] = df['politicalViews'].map(pol_map)

# %%
race_dummies = df['What is your race or ethnicity? (Select all that apply) (d8morv7)'].str.get_dummies(sep=', ')
race_dummies.columns = ['race_' + col.strip().replace(" ", "_").replace("/", "_") for col in race_dummies.columns]
df = pd.concat([df, race_dummies], axis=1)

# %%
# Too many mixed races... simplify?

def collapse_primary_race(val):
    if pd.isna(val): return 'Unknown'
    if 'Black or African American' in val: return 'Black'
    elif 'Hispanic or Latino' in val: return 'Latinx'
    elif 'Asian or Pacific Islander' in val: return 'Asian'
    elif 'White' in val: return 'White'
    elif 'Native American or Indigenous' in val: return 'Indigenous'
    elif 'Middle Eastern or North African' in val: return 'MENA'
    elif 'Another race or ethnicity' in val: return 'Other'
    elif 'Prefer not to say' in val: return 'Prefer not to say'
    else: return 'Multiracial'

df['race_collapsed'] = df['What is your race or ethnicity? (Select all that apply) (d8morv7)'].apply(collapse_primary_race)

# %%
# Set common styling
sns.set(style="whitegrid")

sns.boxplot(x='race_collapsed', y='support_gov_num', data=df)
plt.title("Gov ALPR Support by Race")
plt.xlabel("Race")
plt.ylabel("Support (1–5)")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

sns.boxplot(x='race_collapsed', y='support_private_num', data=df)
plt.title("Private ALPR Support by Race")
plt.xlabel("Race")
plt.ylabel("Support (1–5)")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
sns.boxplot(x='gender', y='support_gov_num', data=df)
plt.title("Gov ALPR Support by Gender")
plt.xlabel("Gender")
plt.ylabel("Support (1–5)")
plt.tight_layout()
plt.show()

sns.boxplot(x='gender', y='support_private_num', data=df)
plt.title("Private ALPR Support by Gender")
plt.xlabel("Gender")
plt.ylabel("Support (1–5)")
plt.tight_layout()
plt.show()

# %%
sns.boxplot(x='education_ord', y='support_gov_num', data=df)
plt.title("Gov ALPR Support by Education Level")
plt.xlabel("Education (ordinal)")
plt.ylabel("Support (1–5)")
plt.tight_layout()
plt.show()

sns.boxplot(x='education_ord', y='support_private_num', data=df)
plt.title("Private ALPR Support by Education Level")
plt.xlabel("Education (ordinal)")
plt.ylabel("Support (1–5)")
plt.tight_layout()
plt.show()

# %%
sns.boxplot(x='householdIncomeScore', y='support_gov_num', data=df)
plt.title("Gov ALPR Support by Household Income")
plt.xlabel("Household Income Score")
plt.ylabel("Support (1–5)")
plt.tight_layout()
plt.show()

sns.boxplot(x='householdIncomeScore', y='support_private_num', data=df)
plt.title("Private ALPR Support by Household Income")
plt.xlabel("Household Income Score")
plt.ylabel("Support (1–5)")
plt.tight_layout()
plt.show()

# %%
sns.scatterplot(x='age', y='support_gov_num', data=df, alpha=0.5)
sns.regplot(x='age', y='support_gov_num', data=df, scatter=False, color='red')
plt.title("Gov ALPR Support by Age")
plt.xlabel("Age")
plt.ylabel("Support (1–5)")
plt.tight_layout()
plt.show()

sns.scatterplot(x='age', y='support_private_num', data=df, alpha=0.5)
sns.regplot(x='age', y='support_private_num', data=df, scatter=False, color='red')
plt.title("Private ALPR Support by Age")
plt.xlabel("Age")
plt.ylabel("Support (1–5)")
plt.tight_layout()
plt.show()

# %%
# Gov ALPR support by political ideology
sns.boxplot(x='political_ord', y='support_gov_num', data=df)
plt.title("Gov ALPR Support by Political Ideology")
plt.xlabel("Political Ideology (1 = Very Conservative … 5 = Very Liberal)")
plt.ylabel("Support (1–5)")
plt.tight_layout()
plt.show()

# Private ALPR support by political ideology
sns.boxplot(x='political_ord', y='support_private_num', data=df)
plt.title("Private ALPR Support by Political Ideology")
plt.xlabel("Political Ideology (1 = Very Conservative … 5 = Very Liberal)")
plt.ylabel("Support (1–5)")
plt.tight_layout()
plt.show()

# %%
sns.violinplot(x='political_ord', y='support_gov_num', data=df, inner=None, color=".8", cut =0)
sns.boxplot(x='political_ord', y='support_gov_num', data=df, whis=[0, 100], width=0.1, color="#f46d43")

plt.title("Gov ALPR Support by Political Ideology")
plt.xlabel("Political Ideology (1 = Very Conservative … 5 = Very Liberal)")
plt.ylabel("Support (1–5)")
plt.tight_layout()
plt.show()

# %%
from matplotlib.ticker import MaxNLocator

sns.violinplot(
    x='political_ord', y='support_gov_num',
    data=df, inner=None, color=".8", cut=0
)
sns.boxplot(
    x='political_ord', y='support_gov_num',
    data=df, whis=[0, 100], width=0.1, color="#f46d43"
)

plt.title("Gov ALPR Support by Political Ideology")
plt.xlabel("Political Ideology (1 = Very Conservative … 5 = Very Liberal)")
plt.ylabel("Support (1–5)")

# force y-axis ticks to be integers
plt.gca().yaxis.set_major_locator(MaxNLocator(integer=True))

plt.tight_layout()
plt.show()

# %%
sns.violinplot(
    x='political_ord', y='support_private_num',
    data=df, inner=None, color=".8", cut=0
)
sns.boxplot(
    x='political_ord', y='support_private_num',
    data=df, whis=[0, 100], width=0.1, color="#f46d43"
)

plt.title("Private ALPR Support by Political Ideology")
plt.xlabel("Political Ideology (1 = Very Conservative … 5 = Very Liberal)")
plt.ylabel("Support (1–5)")

#force y-axis ticks to be integers
plt.gca().yaxis.set_major_locator(MaxNLocator(integer=True))

plt.tight_layout()
plt.show()

# %%
from matplotlib.ticker import MaxNLocator

plt.figure(figsize=(8, 6))

sns.violinplot(
    x='gender',
    y='support_private_num',
    data=df,
    inner=None,
    color=".8",
    cut=0
)

sns.boxplot(
    x='gender',
    y='support_private_num',
    data=df,
    whis=[0, 100],
    width=0.1,
    color="#f46d43"
)

plt.title("Private ALPR Support by Gender")
plt.xlabel("Gender")
plt.ylabel("Support (1–5)")
plt.gca().yaxis.set_major_locator(MaxNLocator(integer=True))
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 6))

sns.violinplot(
    x='gender',
    y='support_gov_num',
    data=df,
    inner=None,
    color=".8",
    cut=0
)

sns.boxplot(
    x='gender',
    y='support_gov_num',
    data=df,
    whis=[0, 100],
    width=0.1,
    color="#f46d43"
)

plt.title("Government ALPR Support by Gender")
plt.xlabel("Gender")
plt.ylabel("Support (1–5)")
plt.gca().yaxis.set_major_locator(MaxNLocator(integer=True))
plt.tight_layout()
plt.show()

# %%
sns.set(style="whitegrid")

g = sns.FacetGrid(df, col='gender', col_wrap=3, height=4, sharex=True, sharey=True)
g.map(sns.histplot, 'support_private_num', bins=5, discrete=True, color="#f46d43")

g.set_titles("{col_name}")
g.set_axis_labels("Support for Private ALPR (1–5)", "Count")
g.set(xlim=(0.5, 5.5), xticks=[1, 2, 3, 4, 5])

plt.suptitle("Distribution of Private ALPR Support by Gender", y=1.05, fontsize=16)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 5))

sns.histplot(data=df[df['gender'] == 'female'], x='support_private_num',
             bins=[1, 2, 3, 4, 5, 6], color='salmon', label='Female', alpha=0.6)

sns.histplot(data=df[df['gender'] == 'male'], x='support_private_num',
             bins=[1, 2, 3, 4, 5, 6], color='steelblue', label='Male', alpha=0.6)

plt.title("Overlapping Histogram of Private ALPR Support by Gender")
plt.xlabel("Support for Private ALPR (1–5)")
plt.ylabel("Count")
plt.xticks([1, 2, 3, 4, 5])
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Hm... how useful is this

sns.histplot(
    data=df,
    x="age", hue="support_private_num", multiple="stack", bins=20,
    palette="viridis"
)
plt.title("Age Distribution by Private ALPR Support Level")
plt.xlabel("Age")
plt.ylabel("Count")
plt.tight_layout()
plt.show()

# %%
age_bins = [18, 25, 35, 45, 55, 65, 75, 90]
age_labels = ['18–24', '25–34', '35–44', '45–54', '55–64', '65–74', '75+']

df['age_bucket'] = pd.cut(df['age'], bins=age_bins, labels=age_labels, right=False)
sns.violinplot(
    x='age_bucket', y='support_private_num',
    data=df, inner=None, color=".8", cut=0
)
sns.boxplot(
    x='age_bucket', y='support_private_num',
    data=df, whis=[0, 100], width=0.1, color="#f46d43"
)

plt.title("Private ALPR Support by Age Group (10-Year Bins)")
plt.xlabel("Age Group")
plt.ylabel("Support (1–5)")
plt.gca().yaxis.set_major_locator(MaxNLocator(integer=True))
plt.tight_layout()
plt.show()

# %%
age_bins = [18, 25, 35, 45, 55, 65, 75, 90]
age_labels = ['18–24', '25–34', '35–44', '45–54', '55–64', '65–74', '75+']

df['age_bucket'] = pd.cut(df['age'], bins=age_bins, labels=age_labels, right=False)
sns.violinplot(
    x='age_bucket', y='support_gov_num',
    data=df, inner=None, color=".8", cut=0
)
sns.boxplot(
    x='age_bucket', y='support_gov_num',
    data=df, whis=[0, 100], width=0.1, color="#f46d43"
)

plt.title("Gov ALPR Support by Age Group (10-Year Bins)")
plt.xlabel("Age Group")
plt.ylabel("Support (1–5)")
plt.gca().yaxis.set_major_locator(MaxNLocator(integer=True))
plt.tight_layout()
plt.show()

# %%
sns.histplot(df['age'], bins=10, kde=False, color='#f46d43')
plt.title("Age Distribution of Survey Respondents")
plt.xlabel("Age")
plt.ylabel("Count")
plt.tight_layout()
plt.show()

# %%
income_order = [
    'Less than $9,999',
    '$10,000 to $24,999',
    '$25,000 to $39,999',
    '$40,000 to $59,999',
    '$60,000 to $84,999',
    '$85,000 to $114,999',
    '$115,000 to $149,999',
    '$150,000 to $199,999',
    '$200,000 or more'
]

df['householdIncome'] = pd.Categorical(df['householdIncome'], categories=income_order, ordered=True)

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(
    x='householdIncome', y='support_gov_num',
    data=df, order=income_order, color="#f46d43"
)
plt.xticks(rotation=45, ha='right')
plt.xlabel("Household Income")
plt.ylabel("Support (1–5)")
plt.title("Support for Government ALPRs by Household Income")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(
    x='householdIncome', y='support_private_num',
    data=df, order=income_order, color="#f46d43"
)
plt.xticks(rotation=45, ha='right')
plt.xlabel("Household Income")
plt.ylabel("Support (1–5)")
plt.title("Support for Private ALPRs by Household Income")
plt.tight_layout()
plt.show()

# %%
# Count of respondents in each household income bracket
income_counts = df['householdIncome'].value_counts().sort_index()

print(income_counts)

plt.figure(figsize=(10, 5))
income_counts.plot(kind='bar', color='#f46d43')
plt.title('Distribution of Household Income Responses')
plt.xlabel('Household Income')
plt.ylabel('Number of Respondents')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# Define ordered categories for readability
education_order = [
    'noSchoolingAtAllCompleted',
    'nurseryTo8thGrade',
    'completedOnlyHighSchoolOrTheEquivalent',
    'completedTradeTechicalVocationalTraing',
    'completedAssociateDegreeOnly',
    'completedBachelorsDegree',
    'completedMastersDegree',
    'completedProfessionalDegree',
    'completedDoctorateDegree'
]

plt.figure(figsize=(12, 6))
sns.countplot(data=df, x='education', order=education_order, color='#f46d43')

plt.title('Distribution of Respondents by Education Level')
plt.xlabel('Education Level')
plt.ylabel('Number of Respondents')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
sns.set(style="whitegrid")

plt.figure(figsize=(12, 6))
sns.boxplot(
    data=df,
    x='education',
    y='support_gov_num',
    color='#f46d43'
)
plt.title("Support for Government ALPRs by Education Level")
plt.xlabel("Education Level")
plt.ylabel("Support (1–5)")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Private ALPRs
plt.figure(figsize=(12, 6))
sns.boxplot(
    data=df,
    x='education',
    y='support_private_num',
    color='#f46d43'
)
plt.title("Support for Private ALPRs by Education Level")
plt.xlabel("Education Level")
plt.ylabel("Support (1–5)")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
race_col = "What is your race or ethnicity? (Select all that apply) (d8morv7)"
gov_support_col = "support_gov_num"   # Replace with actual column name
priv_support_col = "support_private_num" # Replace with actual column name

race_keywords = [
    "White", "Black or African American", "Asian or Pacific Islander",
    "Native American or Indigenous", "Hispanic or Latino",
    "Middle Eastern or North African", "Another race or ethnicity", "Prefer not to say"
]

for race in race_keywords:
    df[race] = df[race_col].str.contains(race, na=False)

race_df_long = df.melt(
    id_vars=[gov_support_col, priv_support_col],
    value_vars=race_keywords,
    var_name="Race",
    value_name="Selected"
)

race_df_long = race_df_long[race_df_long["Selected"] == True]

# Government ALPR Support
plt.figure(figsize=(12, 6))
sns.boxplot(data=race_df_long, x="Race", y=gov_support_col, palette="Set2")
plt.xticks(rotation=45, ha="right")
plt.title("Support for Government ALPRs by Racial Identity")
plt.ylabel("Support (1–5)")
plt.tight_layout()
plt.show()

# Private ALPR Support
plt.figure(figsize=(12, 6))
sns.boxplot(data=race_df_long, x="Race", y=priv_support_col, palette="Set2")
plt.xticks(rotation=45, ha="right")
plt.title("Support for Private ALPRs by Racial Identity")
plt.ylabel("Support (1–5)")
plt.tight_layout()
plt.show()

# %%
race_col = "What is your race or ethnicity? (Select all that apply) (d8morv7)"

def categorize_race(value):
    if pd.isna(value):
        return 'Missing'
    races = value.split(",")
    if len(races) > 1:
        return "Multiracial"
    else:
        return races[0]

df['Race'] = df[race_col].apply(categorize_race)

df['Race'] = df['Race'].replace({
    'Prefer not to say': 'Prefer not to say',
    'Another race or ethnicity': 'Other',
    'Missing': 'Missing'
})

print("New Race categories:", df['Race'].value_counts())

# %%
# Government ALPR support boxplot
plt.figure(figsize=(12, 5))
sns.boxplot(x='Race', y='support_gov_num', color="#f46d43", data=df, order=sorted(df['Race'].unique()))
plt.title("Support for Government ALPRs by Racial Identity")
plt.xlabel("Race")
plt.ylabel("Support (1–5)")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Private ALPR support boxplot
plt.figure(figsize=(12, 5))
sns.boxplot(x='Race', y='support_private_num', color="#f46d43", data=df, order=sorted(df['Race'].unique()))
plt.title("Support for Private ALPRs by Racial Identity")
plt.xlabel("Race")
plt.ylabel("Support (1–5)")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
sns.set(style="whitegrid")

plt.figure(figsize=(10, 5))
sns.countplot(data=df, x='Race', order=df['Race'].value_counts().index, color="#f46d43")

plt.title("Distribution of Respondents by Race")
plt.xlabel("Race")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
